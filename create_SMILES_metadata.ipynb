# %%
from molytica_m.chembl_curation.curate_chembl import create_SMILES_metadata

# %%
create_SMILES_metadata()
# Out:
# Creating SMILES metadata:   9%|▉         | 33/359 [19:39<2:49:16, 31.16s/it]/home/oliver/miniconda3/envs/M/lib/python3.10/site-packages/numpy/core/fromnumeric.py:1761: RuntimeWarning: overflow encountered in reduce
#   return asanyarray(a).trace(offset=offset, axis1=axis1, axis2=axis2, dtype=dtype, out=out)
# /home/oliver/miniconda3/envs/M/lib/python3.10/site-packages/numpy/core/fromnumeric.py:1761: RuntimeWarning: invalid value encountered in reduce
#   return asanyarray(a).trace(offset=offset, axis1=axis1, axis2=axis2, dtype=dtype, out=out)
# Creating SMILES metadata:  12%|█▏        | 43/359 [34:51<2:26:53, 27.89s/it]  [16:15:27] WARNING: not removing hydrogen atom without neighbors
# [16:15:27] WARNING: not removing hydrogen atom without neighbors
# [16:15:27] WARNING: not removing hydrogen atom without neighbors
# Creating SMILES metadata:  18%|█▊        | 66/359 [38:50<52:16, 10.70s/it]  [16:19:27] WARNING: not removing hydrogen atom without neighbors
# ...
