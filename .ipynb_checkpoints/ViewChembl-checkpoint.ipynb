# %%
import sqlite3

# Replace 'your_chembl_database_file.db' with the path to your ChEMBL SQLite file
database_path = 'data/chembl/chembl_33.db'

# Connect to the SQLite database
conn = sqlite3.connect(database_path)

# Create a cursor object
cursor = conn.cursor()

# Execute a query (example: selecting 10 rows from a table)
query = "SELECT COUNT(*) FROM target_dictionary LIMIT 30;"  # Replace 'your_table_name' with the actual table name
cursor.execute(query)

# Fetch and print the results
rows = cursor.fetchall()
for row in rows:
    print(row)
# Out:
# (15398,)

# %%
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
print([x[0] for x in cursor.fetchall()])
print()
# Out:
# ['action_type', 'assay_type', 'chembl_id_lookup', 'confidence_score_lookup', 'curation_lookup', 'chembl_release', 'source', 'relationship_type', 'target_type', 'variant_sequences', 'bioassay_ontology', 'data_validity_lookup', 'activity_smid', 'activity_stds_lookup', 'assay_classification', 'atc_classification', 'bio_component_sequences', 'component_sequences', 'protein_classification', 'domains', 'go_classification', 'structural_alert_sets', 'products', 'frac_classification', 'hrac_classification', 'irac_classification', 'research_stem', 'organism_class', 'patent_use_codes', 'usan_stems', 'version', 'cell_dictionary', 'docs', 'target_dictionary', 'tissue_dictionary', 'molecule_dictionary', 'activity_supp', 'component_class', 'component_domains', 'component_go', 'component_synonyms', 'structural_alerts', 'defined_daily_dose', 'product_patents', 'protein_class_synonyms', 'research_companies', 'assays', 'compound_records', 'binding_sites', 'biotherapeutics', 'compound_properties', 'compound_structural_alerts', 'compound_structures', 'molecule_atc_classification', 'molecule_frac_classification', 'molecule_hierarchy', 'molecule_hrac_classification', 'molecule_irac_classification', 'molecule_synonyms', 'target_components', 'target_relations', 'activities', 'assay_class_map', 'assay_parameters', 'biotherapeutic_components', 'drug_indication', 'drug_mechanism', 'drug_warning', 'formulations', 'metabolism', 'site_components', 'activity_properties', 'activity_supp_map', 'indication_refs', 'ligand_eff', 'mechanism_refs', 'metabolism_refs', 'predicted_binding_domains', 'warning_refs', 'sqlite_stat1']

# %%
conn = sqlite3.connect(database_path)
cursor = conn.cursor()

# Execute a query (example: selecting 10 rows from a table)
query = "PRAGMA table_info(compound_properties);"  # Replace 'your_table_name' with the actual table name
cursor.execute(query)

# Fetch and print the results
rows = cursor.fetchall()
for row in rows:
    print(row)
# Out:
# (0, 'molregno', 'BIGINT', 1, None, 1)
# (1, 'mw_freebase', 'NUMERIC(9, 2)', 0, None, 0)
# (2, 'alogp', 'NUMERIC(9, 2)', 0, None, 0)
# (3, 'hba', 'INTEGER', 0, None, 0)
# (4, 'hbd', 'INTEGER', 0, None, 0)
# (5, 'psa', 'NUMERIC(9, 2)', 0, None, 0)
# (6, 'rtb', 'INTEGER', 0, None, 0)
# (7, 'ro3_pass', 'VARCHAR(3)', 0, None, 0)
# (8, 'num_ro5_violations', 'SMALLINT', 0, None, 0)
# (9, 'cx_most_apka', 'NUMERIC(9, 2)', 0, None, 0)
# (10, 'cx_most_bpka', 'NUMERIC(9, 2)', 0, None, 0)
# (11, 'cx_logp', 'NUMERIC(9, 2)', 0, None, 0)
# (12, 'cx_logd', 'NUMERIC(9, 2)', 0, None, 0)
# (13, 'molecular_species', 'VARCHAR(50)', 0, None, 0)
# (14, 'full_mwt', 'NUMERIC(9, 2)', 0, None, 0)
# (15, 'aromatic_rings', 'INTEGER', 0, None, 0)
# (16, 'heavy_atoms', 'INTEGER', 0, None, 0)
# (17, 'qed_weighted', 'NUMERIC(3, 2)', 0, None, 0)
# (18, 'mw_monoisotopic', 'NUMERIC(11, 4)', 0, None, 0)
# (19, 'full_molformula', 'VARCHAR(100)', 0, None, 0)
# (20, 'hba_lipinski', 'INTEGER', 0, None, 0)
# (21, 'hbd_lipinski', 'INTEGER', 0, None, 0)
# (22, 'num_lipinski_ro5_violations', 'SMALLINT', 0, None, 0)
# (23, 'np_likeness_score', 'NUMERIC(3, 2)', 0, None, 0)

# %%
conn = sqlite3.connect(database_path)
cursor = conn.cursor()

# Execute a query (example: selecting 10 rows from a table)
query = "PRAGMA table_info(activities);"  # Replace 'your_table_name' with the actual table name
cursor.execute(query)

# Fetch and print the results
rows = cursor.fetchall()
for row in rows:
    print(row)
# Out:
# (0, 'activity_id', 'BIGINT', 1, None, 1)
# (1, 'assay_id', 'BIGINT', 1, None, 0)
# (2, 'doc_id', 'BIGINT', 0, None, 0)
# (3, 'record_id', 'BIGINT', 1, None, 0)
# (4, 'molregno', 'BIGINT', 0, None, 0)
# (5, 'standard_relation', 'VARCHAR(50)', 0, None, 0)
# (6, 'standard_value', 'NUMERIC', 0, None, 0)
# (7, 'standard_units', 'VARCHAR(100)', 0, None, 0)
# (8, 'standard_flag', 'SMALLINT', 0, None, 0)
# (9, 'standard_type', 'VARCHAR(250)', 0, None, 0)
# (10, 'activity_comment', 'VARCHAR(4000)', 0, None, 0)
# (11, 'data_validity_comment', 'VARCHAR(30)', 0, None, 0)
# (12, 'potential_duplicate', 'SMALLINT', 0, None, 0)
# (13, 'pchembl_value', 'NUMERIC(4, 2)', 0, None, 0)
# (14, 'bao_endpoint', 'VARCHAR(11)', 0, None, 0)
# (15, 'uo_units', 'VARCHAR(10)', 0, None, 0)
# (16, 'qudt_units', 'VARCHAR(70)', 0, None, 0)
# (17, 'toid', 'INTEGER', 0, None, 0)
# (18, 'upper_value', 'NUMERIC', 0, None, 0)
# (19, 'standard_upper_value', 'NUMERIC', 0, None, 0)
# (20, 'src_id', 'INTEGER', 0, None, 0)
# (21, 'type', 'VARCHAR(250)', 1, None, 0)
# (22, 'relation', 'VARCHAR(50)', 0, None, 0)
# (23, 'value', 'NUMERIC', 0, None, 0)
# (24, 'units', 'VARCHAR(100)', 0, None, 0)
# (25, 'text_value', 'VARCHAR(1000)', 0, None, 0)
# (26, 'standard_text_value', 'VARCHAR(1000)', 0, None, 0)
# (27, 'action_type', 'VARCHAR(50)', 0, None, 0)

# %%
conn = sqlite3.connect(database_path)
cursor = conn.cursor()

# Execute a query (example: selecting 10 rows from a table)
query = "SELECT canonical_smiles FROM compound_structures WHERE molregno IS 180094"  # Replace 'your_table_name' with the actual table name
cursor.execute(query)

# Fetch and print the results
rows = cursor.fetchall()
for row in rows:
    print(row)
# Out:
# ('c1ccc(-c2nc3c(-c4nc5ccccc5o4)cccc3o2)cc1',)

# %%
# Replace 'your_chembl_database_file.db' with the path to your ChEMBL SQLite file
database_path = 'data/chembl/chembl_33.db'

# Connect to the SQLite database
conn = sqlite3.connect(database_path)

# Create a cursor object
cursor = conn.cursor()

# Execute a query (example: selecting 10 rows from a table)
query = "SELECT * FROM target_dictionary WHERE tid IS 12052;"  # Replace 'your_table_name' with the actual table name
cursor.execute(query)

# Fetch and print the results
rows = cursor.fetchall()
for row in rows:
    print(row)

# Close the connection
conn.close()
# Out:
# (12052, 'SINGLE PROTEIN', 'Arachidonate 12-lipoxygenase', 10116, 'Rattus norvegicus', 'CHEMBL2741', 0)

# %%
# Replace 'your_chembl_database_file.db' with the path to your ChEMBL SQLite file
database_path = 'data/chembl/chembl_33.db'

# Connect to the SQLite database
conn = sqlite3.connect(database_path)

# Create a cursor object
cursor = conn.cursor()

# Execute a query (example: selecting 10 rows from a table)
query = "SELECT * FROM target_dictionary WHERE tid IS '80704';"  # Replace 'your_table_name' with the actual table name
cursor.execute(query)

# Fetch and print the results
rows = cursor.fetchall()
for row in rows:
    print(row)
# Out:
# (80704, 'CELL-LINE', 'BJ', 9606, 'Homo sapiens', 'CHEMBL614358', 0)

# %%
from molytica_m.data_tools import id_mapping_tools

# %%
id_mapping_tools.chembl_to_af_uniprot("CHEMBL614358")

# %%
id_mapping_tools.tid_to_af_uniprot(226)
# Out:
# 'P13945'

# %%
# Replace 'your_chembl_database_file.db' with the path to your ChEMBL SQLite file
database_path = 'data/chembl/chembl_33.db'

# Connect to the SQLite database
conn = sqlite3.connect(database_path)

# Create a cursor object
cursor = conn.cursor()

# Execute a query (example: selecting 10 rows from a table)
query = "SELECT * FROM assays WHERE assay_organism IS 'Homo sapiens' LIMIT 30;"  # Replace 'your_table_name' with the actual table name
cursor.execute(query)

# Fetch and print the results
rows = cursor.fetchall()
for row in rows:
    print(row)

# Close the connection
conn.close()
# Out:
# (5, 17430, 'In vitro cell cytotoxicity against 143-B cell lines (Human osteosarcoma cell line)', 'F', None, None, 'Homo sapiens', 9606, None, None, '143B', None, 80001, 'N', 1, 'Intermediate', 1, None, 'CHEMBL615121', 163, 'BAO_0000219', None, None, 'CLD0')
# (6, 17430, 'In vitro cell cytotoxicity against 143-B cell lines (Human osteosarcoma cell line)', 'F', None, None, 'Homo sapiens', 9606, None, None, '143B', None, 80001, 'N', 1, 'Intermediate', 1, None, 'CHEMBL615122', 163, 'BAO_0000219', None, None, 'CLD0')
# (8, 17774, 'In vitro cell cytotoxicity was determined against 143B cell line', 'F', None, None, 'Homo sapiens', 9606, None, None, '143B', None, 80001, 'N', 1, 'Expert', 1, None, 'CHEMBL615124', 163, 'BAO_0000219', None, None, 'CLD0')
# (9, 3801, 'Inhibitory activity against tumor osteosarcoma cell line 143B after 72 hr continuous exposure to compound', 'F', None, None, 'Homo sapiens', 9606, None, None, '143B', None, 80001, 'N', 1, 'Intermediate', 1, None, 'CHEMBL615125', 163, 'BAO_0000219', None, None, 'CLD0')
# (10, 17430, 'In vitro cell cytotoxicity against 143B-LTK cell lines expressed in HSV-1 TK', 'F', None, None, 'Homo sapiens', 9606, None, None, '143B', None, 80001, 'N', 1, 'Intermediate', 1, None, 'CHEMBL615126', 163, 'BAO_0000219', None, None, 'CLD0')
# (11, 17430, 'In vitro cell cytotoxicity against 143B-LTK cell lines expressed in HSV-1 TK', 'F', None, None, 'Homo sapiens', 9606, None, None, '143B', None, 80001, 'N', 1, 'Intermediate', 1, None, 'CHEMBL615127', 163, 'BAO_0000219', None, None, 'CLD0')
# (12, 17774, 'In vitro cell cytotoxicity was determined against 143B-LTK cell line', 'F', None, None, 'Homo sapiens', 9606, None, None, '143B', None, 80001, 'N', 1, 'Expert', 1, None, 'CHEMBL615128', 163, 'BAO_0000219', None, None, 'CLD0')
# (45, 13163, 'The compound was tested at a concentration of 1 uM for inhibitory activity against 17 beta-hydroxysteroid dehydrogenase from human placental microsomes', 'B', None, None, 'Homo sapiens', 9606, None, None, None, None, 20001, 'H', 8, 'Autocuration', 1, None, 'CHEMBL615157', None, 'BAO_0000019', None, None, 'CLD0')
# (46, 13163, 'The compound was tested at a concentration of 1 uM for inhibitory activity against 17 beta-hydroxysteroid dehydrogenase from human placental microsomes', 'B', None, None, 'Homo sapiens', 9606, None, None, None, None, 20001, 'H', 8, 'Autocuration', 1, None, 'CHEMBL615158', None, 'BAO_0000019', None, None, 'CLD0')
# (56, 5116, 'Cytotoxicity against ovarian cancer cell line (1A-9) of humans was determined', 'F', None, None, 'Homo sapiens', 9606, None, None, '1A9', None, 80002, 'N', 1, 'Intermediate', 1, None, 'CHEMBL615179', 506, 'BAO_0000219', None, None, 'CLD0')
# (60, 4787, 'In vitro effective concentration required to reduce the number of human ovarian cancer (1A9) after 3-day incubation', 'F', None, None, 'Homo sapiens', 9606, None, None, '1A9', None, 80002, 'N', 1, 'Expert', 1, None, 'CHEMBL615183', 506, 'BAO_0000219', None, None, 'CLD0')
# (61, 4787, 'In vitro effective concentration required to reduce the number of human ovarian cancer cells (1A9) after 3-day incubation', 'F', None, None, 'Homo sapiens', 9606, None, None, '1A9', None, 80002, 'N', 1, 'Intermediate', 1, None, 'CHEMBL615184', 506, 'BAO_0000219', None, None, 'CLD0')
# (62, 3547, 'Cytotoxic activity against human ovarian cancer (1A9) cell line', 'F', None, None, 'Homo sapiens', 9606, None, None, '1A9', None, 80002, 'N', 1, 'Intermediate', 1, None, 'CHEMBL615185', 506, 'BAO_0000219', None, None, 'CLD0')
# (63, 3547, 'Cytotoxic activity against human ovarian cancer (1A9) cell line; ND=Not determined', 'F', None, None, 'Homo sapiens', 9606, None, None, '1A9', None, 80002, 'N', 1, 'Intermediate', 1, None, 'CHEMBL615186', 506, 'BAO_0000219', None, None, 'CLD0')
# (64, 6726, 'Effective dose of compound against replication of 1A9 cell line was evaluated', 'F', None, None, 'Homo sapiens', 9606, None, None, '1A9', None, 80002, 'N', 1, 'Intermediate', 1, None, 'CHEMBL615187', 506, 'BAO_0000219', None, None, 'CLD0')
# (65, 3455, 'In vitro cytotoxic activity was determined against ovarian cancer (1A9) cell line', 'F', None, None, 'Homo sapiens', 9606, None, None, '1A9', None, 80002, 'N', 1, 'Expert', 1, None, 'CHEMBL885343', 506, 'BAO_0000219', None, None, 'CLD0')
# (66, 5726, 'In vitro cytotoxicity evaluated against human ovarian cancer (1A9 cell line)', 'F', None, None, 'Homo sapiens', 9606, None, None, '1A9', None, 80002, 'N', 1, 'Intermediate', 1, None, 'CHEMBL615188', 506, 'BAO_0000219', None, None, 'CLD0')
# (67, 5726, 'In vitro cytotoxicity evaluated against human ovarian cancer (1A9 cell line); NA is not active', 'F', None, None, 'Homo sapiens', 9606, None, None, '1A9', None, 80002, 'N', 1, 'Intermediate', 1, None, 'CHEMBL615189', 506, 'BAO_0000219', None, None, 'CLD0')
# (68, 5726, 'In vitro percent inhibition evaluated against human ovarian cancer (1A9 cell line) at >20 ug/mL', 'F', None, None, 'Homo sapiens', 9606, None, None, '1A9', None, 80002, 'N', 1, 'Intermediate', 1, None, 'CHEMBL615190', 506, 'BAO_0000219', None, None, 'CLD0')
# (69, 3395, 'Inhibitory activity against Taxol resistant 1A9 cell lines', 'F', None, None, 'Homo sapiens', 9606, None, None, '1A9', None, 80002, 'N', 1, 'Intermediate', 1, None, 'CHEMBL615191', 506, 'BAO_0000219', None, None, 'CLD0')
# (70, 3415, 'Cytotoxicity against human ovarian cancer (1A9) cell lines.', 'F', None, None, 'Homo sapiens', 9606, None, None, '1A9', None, 80002, 'N', 1, 'Expert', 1, None, 'CHEMBL615192', 506, 'BAO_0000219', None, None, 'CLD0')
# (71, 3415, 'Percentage inhibition of human ovarian cancer (1A9) cell lines.', 'F', None, None, 'Homo sapiens', 9606, None, None, '1A9', None, 80002, 'N', 1, 'Expert', 1, None, 'CHEMBL827083', 506, 'BAO_0000219', None, None, 'CLD0')
# (72, 17099, 'Effective dose required for inhibitory activity against 1A9 human tumor cell line.', 'F', None, None, 'Homo sapiens', 9606, None, None, '1A9', None, 80002, 'N', 1, 'Expert', 1, None, 'CHEMBL615193', 506, 'BAO_0000219', None, None, 'CLD0')
# (73, 17099, 'Percent inhibition against 1A9 human tumor cell line at 0.10 ug/mL', 'F', None, None, 'Homo sapiens', 9606, None, None, '1A9', None, 80002, 'N', 1, 'Intermediate', 1, None, 'CHEMBL615194', 506, 'BAO_0000219', None, None, 'CLD0')
# (74, 17099, 'Percent inhibition against 1A9 human tumor cell line at <0.00008 ug/mL', 'F', None, None, 'Homo sapiens', 9606, None, None, '1A9', None, 80002, 'N', 1, 'Intermediate', 1, None, 'CHEMBL615195', 506, 'BAO_0000219', None, None, 'CLD0')
# (75, 17099, 'Percent inhibition against 1A9 human tumor cell line at >10 ug/mL', 'F', None, None, 'Homo sapiens', 9606, None, None, '1A9', None, 80002, 'N', 1, 'Intermediate', 1, None, 'CHEMBL615196', 506, 'BAO_0000219', None, None, 'CLD0')
# (76, 17721, 'Inhibitory concentration against Jurkat cells', 'F', None, None, 'Homo sapiens', 9606, None, None, 'Jurkat', None, 81072, 'N', 1, 'Intermediate', 1, None, 'CHEMBL615197', 503, 'BAO_0000219', None, None, 'CLD0')
# (95, 17653, 'In vitro cytotoxic concentration required to inhibit hepatitisB virus (HBV) replication in 2.2.15 cell line', 'F', None, None, 'Homo sapiens', 9606, None, None, 'HepG2', None, 81020, 'N', 1, 'Expert', 1, None, 'CHEMBL615274', 726, 'BAO_0000219', None, None, 'CLD0')
# (96, 14277, '50% Effective concentration of compound required for inhibiting intracellular viral replicative intermediate DNA in HBV-transfected 2.2.15 cell line.', 'F', None, None, 'Homo sapiens', 9606, None, None, 'HepG2', None, 81020, 'N', 1, 'Intermediate', 1, None, 'CHEMBL615275', 726, 'BAO_0000219', None, None, 'CLD0')
# (97, 1717, 'Antiviral activity against Hepatitis B virus in 2.2.15 cell line', 'F', None, None, 'Homo sapiens', 9606, None, None, 'HepG2', None, 81020, 'N', 1, 'Intermediate', 1, None, 'CHEMBL615276', 726, 'BAO_0000219', None, None, 'CLD0')

# %%
from tqdm.notebook import tqdm
# Replace 'your_chembl_database_file.db' with the path to your ChEMBL SQLite file
database_path = 'data/chembl/chembl_33.db'

# Connect to the SQLite database
conn = sqlite3.connect(database_path)

# Create a cursor object
cursor = conn.cursor()

for x in tqdm(range(0, 6749321, 1000), desc="loading"):
    # Execute a query (example: selecting 10 rows from a table)
    query = f"""
    SELECT activities.standard_type, activities.standard_relation, activities.standard_value, activities.standard_units, assays.tid, compound_structures.canonical_smiles, compound_properties.
    FROM activities 
    JOIN assays ON activities.assay_id = assays.assay_id
    JOIN compound_structures ON activities.molregno = compound_structures.molregno
    JOIN compound_properties ON activities.molregno = compound_properties.molregno
    WHERE assays.assay_organism = 'Homo sapiens'
    LIMIT 1000 OFFSET {x};
    """
    cursor.execute(query)
    
    # Fetch and print the results
    rows = cursor.fetchall()
    for row in rows:
        print(row)

# Close the connection
conn.close()
# Out:
# loading:   0%|          | 0/6750 [00:00<?, ?it/s]
# ('CC50', '=', 600000, 'nM', 80001, 'O=[N+]([O-])O[C@H]1CO[C@H]2[C@@H]1OC[C@H]2O[N+](=O)[O-]')
# ('CC50', '=', 90000, 'nM', 80001, 'O=c1[nH]c(=O)n([C@H]2C[C@H](O)[C@@H](CO)O2)cc1F')
# ('CC50', '=', 340000, 'nM', 80001, 'O=c1[nH]c(=O)n([C@H]2C[C@H](O)[C@@H](CO[N+](=O)[O-])O2)cc1I')
# ('CC50', '=', 2400, 'nM', 80001, 'O=c1[nH]c(=O)n([C@H]2C[C@H](O[N+](=O)[O-])[C@@H](CO)O2)cc1F')
# ('CC50', '=', 7000000, 'nM', 80001, 'O=c1[nH]c(=O)n([C@H]2C[C@H](O)[C@@H](CO)O2)cc1I')
# ('CC50', '=', 200000, 'nM', 80001, 'Nc1nc(=O)n([C@H]2C[C@H](O[N+](=O)[O-])[C@@H](CO)O2)cc1I')
# ('CC50', '=', 580000, 'nM', 80001, 'O=c1[nH]c(=O)n([C@H]2C[C@H](O[N+](=O)[O-])[C@@H](CO)O2)cc1I')
# ('CC50', '=', 960, 'nM', 80001, 'O=c1ccn([C@H]2C[C@H](Oc3no[n+]([O-])c3S(=O)(=O)c3ccccc3)[C@@H](CO)O2)c(=O)[nH]1')
# ('CC50', '=', 3600, 'nM', 80001, 'Cc1cn([C@H]2C[C@H](O)[C@@H](COc3no[n+]([O-])c3S(=O)(=O)c3ccccc3)O2)c(=O)[nH]c1=O')
# ('CC50', '=', 520, 'nM', 80001, 'O=c1[nH]c(=O)n([C@H]2C[C@H](Oc3no[n+]([O-])c3S(=O)(=O)c3ccccc3)[C@@H](CO)O2)cc1C(F)(F)F')
# ('CC50', '=', 240, 'nM', 80001, 'O=c1[nH]c(=O)n([C@H]2C[C@H](Oc3no[n+]([O-])c3S(=O)(=O)c3ccccc3)[C@@H](CO)O2)cc1F')
# ('CC50', '=', 70, 'nM', 80001, 'COc1no[n+]([O-])c1S(=O)(=O)c1ccccc1')
# ('CC50', '=', 40, 'nM', 80001, 'O=S(=O)(c1ccccc1)c1no[n+]([O-])c1S(=O)(=O)c1ccccc1')
# ('CC50', '=', 560, 'nM', 80001, 'O=c1[nH]c(=O)n([C@H]2C[C@H](Oc3no[n+]([O-])c3S(=O)(=O)c3ccccc3)[C@@H](CO)O2)cc1I')
# ('CC50', '=', 90000, 'nM', 80001, 'O=c1[nH]c(=O)n([C@H]2C[C@H](O)[C@@H](CO)O2)cc1I')
# ('CC50', '=', 3300, 'nM', 80001, 'O=c1ccn([C@H]2C[C@H](O)[C@@H](COc3no[n+]([O-])c3S(=O)(=O)c3ccccc3)O2)c(=O)[nH]1')
# ('CC50', '=', 3200, 'nM', 80001, 'O=c1[nH]c(=O)n([C@H]2C[C@H](O)[C@@H](COc3no[n+]([O-])c3S(=O)(=O)c3ccccc3)O2)cc1F')
# ('CC50', '=', 720, 'nM', 80001, 'Cc1cn([C@H]2C[C@H](Oc3no[n+]([O-])c3S(=O)(=O)c3ccccc3)[C@@H](CO)O2)c(=O)[nH]c1=O')
# ('CC50', '=', 540, 'nM', 80001, 'O=c1[nH]c(=O)n([C@H]2C[C@H](O)[C@@H](COc3no[n+]([O-])c3S(=O)(=O)c3ccccc3)O2)cc1I')
# ('CC50', '=', 7000000, 'nM', 80001, 'O=[N+]([O-])O[C@H]1CO[C@H]2[C@@H]1OC[C@H]2O[N+](=O)[O-]')
# ('CC50', '=', 600000, 'nM', 80001, 'Cc1cn([C@H]2C[C@H](O)[C@@H](CO)O2)c(=O)[nH]c1=O')
# ('IC50', '=', 118000, 'nM', 80001, 'COC(=O)C1C(C(=O)O)[C@@H]2CC[C@H]1O2')
# ('IC50', '=', 43000, 'nM', 80001, 'O=C1OC(=O)[C@H]2[C@@H]1[C@H]1CC[C@H]2O1')
# ('IC50', '>', 1000000, 'nM', 80001, 'CCCOC1OC(=O)[C@H]2[C@@H]1[C@@H]1CC[C@H]2O1')
# ('IC50', '=', 450000, 'nM', 80001, 'CCCOC(=O)C1C(C(=O)O)[C@@H]2CC[C@H]1O2')
# ('IC50', '=', 10000, 'nM', 80001, 'C[C@@]12C(=O)OC(=O)[C@]1(C)[C@H]1CC[C@@H]2O1')
# ('IC50', '=', 437000, 'nM', 80001, 'CCOC(=O)C1C(C(=O)O)[C@@H]2CC[C@H]1O2')
# ('IC50', '>', 1000000, 'nM', 80001, 'COC1OC(=O)[C@H]2[C@@H]1[C@@H]1CC[C@H]2O1')
# ('IC50', '=', 103000, 'nM', 80001, 'CCOC1OC(=O)[C@H]2[C@@H]1[C@@H]1CC[C@H]2O1')
# ('CC50', '=', 1000000, 'nM', 80001, 'Cc1cn([C@H]2C[C@H](O[N+](=O)[O-])[C@@H](CO)O2)c(=O)nc1N')
# ('CC50', '=', 200000, 'nM', 80001, 'Nc1ccn([C@H]2C[C@H](O[N+](=O)[O-])[C@@H](CO)O2)c(=O)n1')
# ('CC50', '=', 700000, 'nM', 80001, 'O=[N+]([O-])O[C@H]1CO[C@H]2[C@@H]1OC[C@H]2O[N+](=O)[O-]')
# ('CC50', '=', 100000, 'nM', 80001, 'O=c1[nH]c(=O)n([C@H]2C[C@H](O)[C@@H](CO)O2)cc1F')
# ('CC50', '=', 21000, 'nM', 80001, 'O=c1[nH]c(=O)n([C@H]2C[C@H](O)[C@@H](CO[N+](=O)[O-])O2)cc1I')
# ('CC50', '=', 74000, 'nM', 80001, 'O=c1[nH]c(=O)n([C@H]2C[C@H](O[N+](=O)[O-])[C@@H](CO)O2)cc1F')
# ('CC50', '=', 7400000, 'nM', 80001, 'O=c1[nH]c(=O)n([C@H]2C[C@H](O)[C@@H](CO)O2)cc1I')
# ('CC50', '=', 850000, 'nM', 80001, 'O=c1ccn([C@H]2C[C@H](O[N+](=O)[O-])[C@@H](CO)O2)c(=O)[nH]1')
# ('CC50', '=', 200000, 'nM', 80001, 'Nc1nc(=O)n([C@H]2C[C@H](O[N+](=O)[O-])[C@@H](CO)O2)cc1I')
# ('CC50', '=', 410000, 'nM', 80001, 'O=c1[nH]c(=O)n([C@H]2C[C@H](O[N+](=O)[O-])[C@@H](CO)O2)cc1I')
# ('CC50', '=', 2900, 'nM', 80001, 'O=c1ccn([C@H]2C[C@H](Oc3no[n+]([O-])c3S(=O)(=O)c3ccccc3)[C@@H](CO)O2)c(=O)[nH]1')
# ('CC50', '=', 5600, 'nM', 80001, 'Cc1cn([C@H]2C[C@H](O)[C@@H](COc3no[n+]([O-])c3S(=O)(=O)c3ccccc3)O2)c(=O)[nH]c1=O')
# ('CC50', '=', 480, 'nM', 80001, 'O=c1[nH]c(=O)n([C@H]2C[C@H](Oc3no[n+]([O-])c3S(=O)(=O)c3ccccc3)[C@@H](CO)O2)cc1C(F)(F)F')
# ('CC50', '=', 840, 'nM', 80001, 'O=c1[nH]c(=O)n([C@H]2C[C@H](Oc3no[n+]([O-])c3S(=O)(=O)c3ccccc3)[C@@H](CO)O2)cc1F')
# ('CC50', '=', 320, 'nM', 80001, 'COc1no[n+]([O-])c1S(=O)(=O)c1ccccc1')
# ('CC50', '=', 28, 'nM', 80001, 'O=S(=O)(c1ccccc1)c1no[n+]([O-])c1S(=O)(=O)c1ccccc1')
# ('CC50', '=', 1300, 'nM', 80001, 'O=c1[nH]c(=O)n([C@H]2C[C@H](Oc3no[n+]([O-])c3S(=O)(=O)c3ccccc3)[C@@H](CO)O2)cc1I')
# ('CC50', '=', 100000, 'nM', 80001, 'O=c1[nH]c(=O)n([C@H]2C[C@H](O)[C@@H](CO)O2)cc1I')
# ('CC50', '=', 6300, 'nM', 80001, 'O=c1ccn([C@H]2C[C@H](O)[C@@H](COc3no[n+]([O-])c3S(=O)(=O)c3ccccc3)O2)c(=O)[nH]1')
# ('CC50', '=', 2000, 'nM', 80001, 'O=c1[nH]c(=O)n([C@H]2C[C@H](O)[C@@H](COc3no[n+]([O-])c3S(=O)(=O)c3ccccc3)O2)cc1F')
# ('CC50', '=', 880, 'nM', 80001, 'Cc1cn([C@H]2C[C@H](Oc3no[n+]([O-])c3S(=O)(=O)c3ccccc3)[C@@H](CO)O2)c(=O)[nH]c1=O')
# ('CC50', '=', 710, 'nM', 80001, 'O=c1[nH]c(=O)n([C@H]2C[C@H](O)[C@@H](COc3no[n+]([O-])c3S(=O)(=O)c3ccccc3)O2)cc1I')
# ('CC50', '=', 7400000, 'nM', 80001, 'O=[N+]([O-])O[C@H]1CO[C@H]2[C@@H]1OC[C@H]2O[N+](=O)[O-]')
# ('CC50', '=', 700000, 'nM', 80001, 'Cc1cn([C@H]2C[C@H](O)[C@@H](CO)O2)c(=O)[nH]c1=O')
# ('Inhibition', '=', 3, '%', 20001, 'C[C@]12CCC(=O)C=C1C(=O)CC1C2CC[C@@]2(C)C1CC[C@@]21CCC(=O)O1')
# ('Inhibition', '=', 3, '%', 20001, 'C[C@]12CCC(=O)C=C1CC[C@@H]1[C@@H]2CC[C@@]2(C)[C@H]1CC[C@@]21CCC(=O)O1')
# ('Inhibition', '=', 11, '%', 20001, 'C[C@]12CC[C@@]3(CCC(=O)O3)CC1CC[C@@H]1[C@@H]2CC[C@@]2(C)[C@H]1CC[C@@]21CCC(=O)O1')
# ('Inhibition', '=', 11, '%', 20001, 'C[C@]12CC[C@@H]3c4ccc(OCc5ccccc5)cc4CC[C@H]3[C@@H]1CC[C@@]21CCC(=O)O1')
# ('Inhibition', '=', 25, '%', 20001, 'CC(=O)S[C@@H]1CC2=CC(=O)CC[C@]2(C)C2CC[C@@]3(C)C(CC[C@@]34CCC(=O)O4)C21')
# ('Inhibition', '=', 55, '%', 20001, 'COc1ccc2c(c1)CC[C@@H]1[C@@H]2CC[C@@]2(C)[C@H]1CC[C@@]21CCC(=O)O1')
# ('Inhibition', '=', 28, '%', 20001, 'C[C@]12CCC(=O)CC1C(=O)C[C@@H]1[C@@H]2CC[C@@]2(C)[C@H]1CC[C@@]21CCC(=O)O1')
# ('Inhibition', '=', 6, '%', 20001, 'C[C@]12C=CC(=O)C=C1CCC1C2CC[C@@]2(C)C1CC[C@@]21CCC(=O)O1')
# ('Inhibition', '=', 81, '%', 20001, 'C[C@]12CC[C@@H]3c4ccc(O)cc4CC[C@H]3[C@@H]1CC[C@@]21CCC(=O)O1')
# ('Inhibition', '=', 0, '%', 20001, 'C[C@]12C=CC(=O)CC1CCC1C2CC[C@@]2(C)C1CC[C@@]21CCC(=O)O1')
# ('Inhibition', '=', 25, '%', 20001, 'C[C@]12CCC(=O)CC1CC[C@@H]1[C@@H]2CC[C@@]2(C)[C@H]1CC[C@@]21CCC(=O)O1')
# ('IC50', '=', 60, 'nM', 80002, 'COc1ccc2c(c1)C=CCc1cc(OC)c(OC)c(OC)c1-2')
# ('IC50', '=', 2.7, 'nM', 80002, 'COc1ccc2c(c1)[C@@H](NC(=O)CCl)CCc1cc(OC)c(OC)c(OC)c1-2')
# ('IC50', '=', 11.9, 'nM', 80002, 'COc1cc2c(c(OC)c1OC)-c1ccc(OC)c(=O)cc1[C@@H](NC(C)=O)CC2')
# ('IC50', '=', 82, 'nM', 80002, 'COc1ccc2c(c1)[C@@H]1O[C@@H]1Cc1cc(OC)c(OC)c(OC)c1-2')
# ('ED50', '>', 20, 'ug ml-1', 80002, 'COc1cc2nc(-c3cccc(F)c3)nc(O)c2cc1OC')
# ('ED50', '=', 7.8, 'ug ml-1', 80002, 'COc1cc2nc(-c3ccc4ccccc4c3)nc(O)c2cc1OC')
# ('ED50', '=', 17.5, 'ug ml-1', 80002, 'COc1cccc(-c2nc(O)c3cc(OC)c(OC)cc3n2)c1')
# ('ED50', None, None, None, 80002, 'COc1cccc(-c2nc(O)c3ccccc3n2)c1')
# ('ED50', '=', 4.7, 'ug ml-1', 80002, 'COc1cccc(-c2nc(O)c3cc(OC)ccc3n2)c1')
# ('ED50', '=', 8, 'ug ml-1', 80002, 'Oc1nc(-c2ccc3ccccc3c2)nc2ccccc12')
# ('ED50', '>', 20, 'ug ml-1', 80002, 'Oc1nc(-c2cccc(F)c2)nc2ccccc12')
# ('ED50', '=', 16, 'ug ml-1', 80002, 'COc1cc2nc(-c3ccc(F)cc3)nc(O)c2cc1OC')
# ('ED50', '>', 20, 'ug ml-1', 80002, 'Oc1nc(-c2ccc(F)cc2)nc2ccccc12')
# ('ED50', '>', 20, 'ug ml-1', 80002, 'COc1cc2nc(-c3ccccc3F)nc(O)c2cc1OC')
# ('ED50', '=', 17.1, 'ug ml-1', 80002, 'Oc1nc(-c2ccccc2F)nc2ccccc12')
# ('ED50', '=', 5.8, 'ug ml-1', 80002, 'CC1(C)C=Cc2c(ccc3ccc(O)nc23)O1')
# ('ED50', '=', 10, 'ug ml-1', 80002, 'CC1(C)C=Cc2c(ccc3c(-c4ccccc4)cc(O)nc23)O1')
# ('ED50', '=', 12, 'ug ml-1', 80002, 'Cc1cc(S)nc2c3c(ccc12)OC(C)(C)C=C3')
# ('ED50', '>', 40, 'ug ml-1', 80002, 'CCCc1cc(O)nc2c3c(ccc12)OC(C)(C)C=C3')
# ('ED50', None, None, None, 80002, 'Cc1cc(=O)n(C(=O)OC(C)(C)C)c2c3c(ccc12)OC(C)(C)C=C3')
# ('ED50', None, None, None, 80002, 'Cc1cc2c(C)c(C)c(O)nc2c2c1OC(C)(C)C=C2')
# ('ED50', None, None, None, 80002, 'Cc1cc(O)nc2c3c(ccc12)OC(C)(C)C=C3')
# ('ED50', None, None, None, 80002, 'Cc1c(O)nc2c3c(ccc2c1C)OC(C)(C)C=C3')
# ('ED50', '<', 1.6, 'uM', 80002, 'COc1cc([C@@H]2c3cc4c(cc3[C@@H](Nc3ccc([N+](=O)[O-])cc3)[C@H]3COC(=O)[C@H]23)OCO4)cc(OC)c1O')
# ('ED50', '=', 4.2, 'uM', 80002, 'COc1cc([C@@H]2c3cc4c(cc3[C@@H](Nc3ccc([N+](=O)[O-])cc3)[C@H]3COS(=O)OC[C@H]23)OCO4)cc(OC)c1O')
# ('ED50', '>', 20, 'ug ml-1', 80002, 'CCC(CC)C1NC(C(=O)O)Cc2c1[nH]c1cc(OC)ccc21')
# ('ED50', '>', 10, 'ug ml-1', 80002, 'Cc1cc(O)n2c(n1)nc1ccccc12')
# ('ED50', '=', 7, 'ug ml-1', 80002, 'COc1ccc2c3ccn(C)c(C)c-3nc2c1')
# ('ED50', '=', 1.4, 'ug ml-1', 80002, 'CCCCCCCCCCOc1ccc2c(c1)[nH]c1c(C)nccc12')
# ('ED50', '=', 4.5, 'ug ml-1', 80002, 'CC(=O)Oc1ccc2c(c1)[nH]c1c(C)nccc12')
# ('ED50', '=', 2.3, 'ug ml-1', 80002, 'COc1cc2[nH]c3c(C)nccc3c2cc1Br')
# ('ED50', '>', 10, 'ug ml-1', 80002, 'COc1ccc2c3c([nH]c2c1)C(C)N(N=O)CC3')
# ('ED50', '=', 1.6, 'ug ml-1', 80002, 'COc1ccc2c(c1)[nH]c1c(C)nccc12')
# ('ED50', '=', 3.8, 'ug ml-1', 80002, 'Cc1[nH]ccc2c1[nH]c1cc(=O)ccc12')
# ('ED50', '<', 1.3, 'ug ml-1', 80002, 'CCCn1c2cc(OC)ccc2c2cc[n+](C)c(C)c21.[I-]')
# ('ED50', '=', 2.2, 'ug ml-1', 80002, 'CCCCn1c2cc(OC)ccc2c2ccnc(C)c21')
# ('ED50', '=', 7, 'ug ml-1', 80002, 'COc1ccc2c(c1)[nH]c1c(C)[n+](C)ccc12.[I-]')
# ('ED50', '>', 20, 'ug ml-1', 80002, 'CCCCCCCCC1NC(C(=O)O)Cc2c1[nH]c1cc(OC)ccc21')
# ('ED50', '>', 10, 'ug ml-1', 80002, 'Br.COc1ccc2c3c([nH]c2c1)C(C)=NCC3')
# ('ED50', '=', 6.1, 'ug ml-1', 80002, 'Cc1nccc2c1[nH]c1ccccc12')
# ('ED50', '=', 7.9, 'ug ml-1', 80002, 'Cc1nccc2c1[nH]c1cc(OC(C)C)ccc12')
# ('ED50', '>', 20, 'ug ml-1', 80002, 'COS(=O)(=O)O.Cc1nccc2c1[nH]c1ccccc12')
# ('ED50', '=', 1.9, 'ug ml-1', 80002, 'CCCCCCOc1ccc2c(c1)[nH]c1c(C)nccc12')
# ('ED50', '=', 8, 'ug ml-1', 80002, 'CCCCCCCCCCCCCCCCOc1ccc2c(c1)[nH]c1c(C)nccc12')
# ('ED50', '=', 1.9, 'ug ml-1', 80002, 'Br.COc1cc2[nH]c3c(C)nccc3c2cc1Br')
# ('ED50', '=', 1.8, 'ug ml-1', 80002, 'COc1ccc2c3ccnc(C)c3n(C)c2c1')
# ('ED50', '=', 19.5, 'ug ml-1', 80002, 'Cc1nccc2c1[nH]c1cc(OC(=O)C34CCC(C)(C(=O)O3)C4(C)C)ccc12')
# ('ED50', '=', 1.8, 'ug ml-1', 80002, 'CCn1c2cc(OC)ccc2c2ccnc(C)c21')
# ('ED50', '=', 0.3, 'ug ml-1', 80002, 'COc1ccc2c(c1)[nH]c1c(/C=C/c3ccc([N+](=O)[O-])cc3)nccc12')
# ('ED50', '=', 8, 'ug ml-1', 80002, 'CCOc1ccc2c(c1)[nH]c1c(C)nccc12')
# ('ED50', '=', 2, 'ug ml-1', 80002, 'CCC[n+]1ccc2c([nH]c3cc(OC)ccc32)c1C.[I-]')
# ('ED50', '=', 7.5, 'ug ml-1', 80002, 'COC(=O)Cc1cccc2c(O)cc(-c3ccccc3F)nc12')
# ('ED50', '=', 0.04, 'ug ml-1', 80002, 'O=C(O)Cc1cccc2c(O)cc(-c3ccccc3)nc12')
# ('ED50', '>', 20, 'ug ml-1', 80002, 'O=C(O)Cc1ccc2nc(-c3ccccc3F)cc(O)c2c1')
# ('ED50', '>', 20, 'ug ml-1', 80002, 'COC(=O)Cc1cccc2c(O)cc(-c3ccccc3)nc12')
# ('ED50', '=', 0.02, 'ug ml-1', 80002, 'O=C(O)Cc1cccc2c(O)cc(-c3ccccc3F)nc12')
# ('ED50', '>', 20, 'ug ml-1', 80002, 'O=C(O)Cc1ccc2c(O)cc(-c3ccccc3F)nc2c1')
# ('ED50', None, None, None, 80002, 'O=C(O)Cc1cccc2nc(-c3ccccc3F)cc(O)c12')
# ('Inhibition', '=', 37, '%', 80002, 'O=C(O)Cc1ccc2nc(-c3ccccc3F)cc(O)c2c1')
# ('Inhibition', '=', 30, '%', 80002, 'COC(=O)Cc1cccc2c(O)cc(-c3ccccc3)nc12')
# ('Inhibition', '=', 15, '%', 80002, 'O=C(O)Cc1ccc2c(O)cc(-c3ccccc3F)nc2c1')
# ('IC50', '>', 2500, 'nM', 80002, 'COc1ccc2cc1Oc1ccc(cc1)CC(O)COC(=O)CC2')
# ('IC50', '>', 2500, 'nM', 80002, 'COc1ccc2cc1Oc1ccc(cc1)C1OC1COC(=O)CC2')
# ('IC50', '>', 2500, 'nM', 80002, 'COc1cc2c(c(OC)c1OC)-c1ccc(OC)c(=O)cc1[C@@H](NC(C)=O)CC2')
# ('IC50', '>', 2500, 'nM', 80002, 'COc1ccc2cc1Oc1ccc(cc1)CC(I)COC(=O)CC2')
# ('IC50', '>', 2500, 'nM', 80002, 'COc1c(Br)cc2cc1Oc1ccc(cc1)CC(O)COC(=O)CC2')
# ('IC50', '>', 2500, 'nM', 80002, 'COc1ccc2cc1Oc1ccc(cc1)/C=C\\COC(=O)CC2')
# ('ED50', '=', 3.2, 'ug ml-1', 80002, 'CC(=O)Oc1ccc([C@@H]2c3c(OC(C)=O)cc(OC(C)=O)cc3[C@H]3[C@H](c4ccc(OC(C)=O)cc4)c4c(OC(C)=O)cc(OC(C)=O)cc4[C@@H]23)cc1')

# ('CC50', '>', 50000, 'nM', 81020, 'Nc1ccn(/C=C2\\CC2(CO)CO)c(=O)n1')
# ('CC50', '>', 50000, 'nM', 81020, 'Cc1cn(/C=C2/CC2(CO)CO)c(=O)[nH]c1=O')
# ('CC50', '=', 90000, 'nM', 81020, 'COc1nc(N)nc2c1ncn2/C=C1\\CC1(CO)CO')
# ('CC50', '=', 48000, 'nM', 81020, 'Nc1nc(N)c2ncn(/C=C3\\CC3(CO)CO)c2n1')
# ('CC50', '>', 50000, 'nM', 81020, 'Nc1nc2c(ncn2/C=C2\\CC2(CO)CO)c(=O)[nH]1')
# ('CC50', '>', 50000, 'nM', 81020, 'Nc1ncnc2c1ncn2/C=C1/CC1(CO)CO')
# ('CC50', '>', 50000, 'nM', 81020, 'Nc1ccn(/C=C2/CC2(CO)CO)c(=O)n1')
# ('CC50', '>', 50000, 'nM', 81020, 'Cc1cn(/C=C2\\CC2(CO)CO)c(=O)[nH]c1=O')
# ('EC50', '=', 0.25, 'ug.mL-1', 81020, 'Cc1cn(C2C/C(=N\\O)C(CO)O2)c(=O)[nH]c1=O')
# ('EC50', '>', 10000, 'nM', 81020, 'Nc1nc(O)c2ncn([C@H]3CC[C@@H](CO)O3)c2n1')
# ('EC50', '>', 10000, 'nM', 81020, 'OCC1C=CC(n2cnc3c(O)ncnc32)O1')
# ('EC50', '>', 10000, 'nM', 81020, 'Nc1nc(O)c2ncn(C3C=CC(CO)O3)c2n1')
# ('EC50', '=', 1200, 'nM', 81020, 'Nc1ncnc2c1ncn2[C@H]1C=C[C@@H](CO)O1')
# ('EC50', '=', 6000, 'nM', 81020, 'Nc1ncnc2c1ncn2[C@H]1CC[C@@H](CO)O1')
# ('EC50', '>', 10000, 'nM', 81020, 'O=c1[nH]cnc2c1ncn2[C@H]1CC[C@@H](CO)O1')
# ('EC50', '=', 1200, 'nM', 81020, 'Nc1ccn([C@H]2C[Se][C@@H](CO)O2)c(=O)n1')
# ('EC50', '=', 8, 'nM', 81020, 'Nc1ccn([C@@H]2CS[C@H](CO)O2)c(=O)n1')
# ('EC50', '=', 1200, 'nM', 81020, 'Nc1nc(=O)n([C@H]2C[Se][C@@H](CO)O2)cc1F')
# ('EC50', None, None, 'nM', 81020, 'Nc1nc(=O)n([C@@H]2C[Se][C@@H](CO)O2)cc1F')
# ('EC50', None, None, 'nM', 81020, 'Nc1ccn([C@@H]2C[Se][C@@H](CO)O2)c(=O)n1')
# ('IC50', '=', 0.7, 'ug.mL-1', 81020, 'Nc1nc(N)c2ccn([C@@H]3O[C@H](CO)[C@@H](O)[C@@H]3F)c2n1')
# ('IC50', '=', 2.1, 'ug.mL-1', 81020, 'Nc1ccn([C@H]2CC[C@@H](CO)O2)c(=O)n1')
# ('IC50', '>', 30, 'ug.mL-1', 81020, 'Nc1nc(N)c2ccn(C3OC(CO)CC3F)c2n1')
# ('IC50', '=', 60, 'ug.mL-1', 81020, 'Nc1nc(O)c2ccn([C@@H]3O[C@H](CO)[C@@H](O)[C@@H]3F)c2n1')
# ('IC50', '=', 200000, 'nM', 81020, 'Nc1nc(O)c2ncn([C@H]3CC[C@@H](CO)O3)c2n1')
# ('IC50', '=', 50000, 'nM', 81020, 'OCC1C=CC(n2cnc3c(O)ncnc32)O1')
# ('IC50', '=', 50000, 'nM', 81020, 'Nc1nc(O)c2ncn(C3C=CC(CO)O3)c2n1')
# ('IC50', '=', 70000, 'nM', 81020, 'Nc1ncnc2c1ncn2[C@H]1C=C[C@@H](CO)O1')
# ('IC50', '>', 200000, 'nM', 81020, 'Nc1ncnc2c1ncn2[C@H]1CC[C@@H](CO)O1')
# ('IC50', '>', 200000, 'nM', 81020, 'O=c1[nH]cnc2c1ncn2[C@H]1CC[C@@H](CO)O1')
# ('TC50', '=', 630, 'ug ml-1', 81020, 'Nc1nc(N)c2ccn([C@@H]3O[C@H](CO)[C@@H](O)[C@@H]3F)c2n1')
# ('TC50', '=', 64, 'ug ml-1', 81020, 'Nc1ccn([C@H]2CC[C@@H](CO)O2)c(=O)n1')
# ('TC50', '=', 149, 'ug ml-1', 81020, 'Nc1nc(N)c2ccn(C3OC(CO)CC3F)c2n1')
# ('TC50', '>', 100, 'ug ml-1', 81020, 'Nc1nc(O)c2ccn([C@@H]3O[C@H](CO)[C@@H](O)[C@@H]3F)c2n1')
# ('CC50', '>', 200000, 'nM', 50587, 'Nc1nc(N2CCCC2)c2ncn(C3CC(O)C(CO)S3)c2n1')
# ('CC50', '>', 200000, 'nM', 50587, 'CCN(C)c1nc(N)nc2c1ncn2C1CC(O)C(CO)S1')
# ('CC50', '>', 200000, 'nM', 50587, 'CSc1nc(N)nc2c1ncn2C1CC(O)C(CO)S1')
# ('CC50', '=', 14000, 'nM', 50587, 'COc1nc(N)nc2c1ncn2C1CC(O)C(CO)S1')
# ('CC50', '>', 200, 'nM', 50587, 'CCCNc1nc(N)nc2c1ncn2C1CC(O)C(CO)S1')
# ('CC50', '>', 200, 'nM', 50587, 'Nc1nc(OCC2CC2)c2ncn(C3CC(O)C(CO)S3)c2n1')
# ('CC50', '>', 200, 'nM', 50587, 'Nc1nc(Cl)c2ncn(C3CC(O)C(CO)S3)c2n1')
# ('CC50', '=', 77000, 'nM', 50587, 'Nc1nc(NC2CC2)c2ncn(C3CC(O)C(CO)S3)c2n1')
# ('CC50', '>', 200000, 'nM', 50587, 'CC(C)Nc1nc(N)nc2c1ncn2C1CC(O)C(CO)S1')
# ('CC50', '>', 200000, 'nM', 50587, 'Nc1nc(N2CCCCC2)c2ncn(C3CC(O)C(CO)S3)c2n1')
# ('CC50', '>', 200, 'nM', 50587, 'C=CCNc1nc(N)nc2c1ncn2C1CC(O)C(CO)S1')
# ('CC50', '=', 101000, 'nM', 50587, 'CN(c1nc(N)nc2c1ncn2C1CC(O)C(CO)S1)C1CC1')
# ('CC50', '=', 13000, 'nM', 50587, 'Nc1nc(O)c2ncn(C3CC(O)C(CO)S3)c2n1')
# ('EC50', '>', 10000, 'nM', 50587, 'O=c1[nH]c(=O)n([C@H]2O[C@@H](CO)[C@H](O)[C@H]2F)cc1F')
# ('EC50', '=', 1400, 'nM', 50587, 'Nc1ccn([C@@H]2O[C@H](CO)[C@@H](O)[C@@H]2F)c(=O)n1')
# ('EC50', '>', 10000, 'nM', 50587, 'CCc1cn([C@H]2O[C@@H](CO)[C@H](O)[C@@H]2F)c(=O)[nH]c1=O')
# ('EC50', '>', 10000, 'nM', 50587, 'O=c1[nH]c(=O)n([C@@H]2O[C@H](CO)[C@@H](O)[C@@H]2F)cc1C(F)(F)F')
# ('EC50', '>', 10000, 'nM', 50587, 'Nc1nc(=O)n([C@H]2O[C@@H](CO)[C@H](O)[C@H]2F)cc1F')
# ('EC50', '=', 5000, 'nM', 50587, 'Nc1nc(=O)n([C@@H]2O[C@H](CO)[C@@H](O)[C@@H]2F)cc1I')
# ('EC50', '>', 10000, 'nM', 50587, 'O=c1[nH]c(=O)n([C@H]2O[C@@H](CO)[C@H](O)[C@H]2F)cc1Br')
# ('EC50', '>', 10000, 'nM', 50587, 'Nc1nc(=O)n([C@H]2O[C@@H](CO)[C@H](O)[C@H]2F)cc1Cl')
# ('EC50', '>', 10000, 'nM', 50587, 'O=c1[nH]c(=O)n([C@H]2O[C@@H](CO)[C@H](O)[C@@H]2F)cc1/C=C/Br')
# ('EC50', '>', 10000, 'nM', 50587, 'Nc1nc(=O)n([C@H]2O[C@@H](CO)[C@H](O)[C@H]2F)cc1Br')
# ('EC50', '>', 10000, 'nM', 50587, 'C#Cc1cn([C@H]2O[C@@H](CO)[C@H](O)[C@H]2F)c(=O)[nH]c1=O')
# ('EC50', '>', 10000, 'nM', 50587, 'O=c1[nH]c(=O)n([C@H]2O[C@@H](CO)[C@H](O)[C@H]2F)cc1Cl')
# ('EC50', '=', 100, 'nM', 50587, 'Cc1cn([C@@H]2O[C@H](CO)[C@@H](O)[C@@H]2F)c(=O)[nH]c1=O')
# ('EC50', '>', 10000, 'nM', 50587, 'O=c1[nH]c(=O)n([C@@H]2O[C@H](CO)[C@@H](O)[C@H]2F)cc1I')
# ('EC50', '>', 10000, 'nM', 50587, 'Nc1ncnc2c1ncn2[C@@H]1O[C@H](CO)C[C@@H]1F')
# ('EC50', '=', 4000, 'nM', 50587, 'Nc1ccn([C@@H]2O[C@H](CO)C[C@@H]2F)c(=O)n1')
# ('EC50', None, None, 'nM', 50587, 'Cc1cn([C@H]2C[C@H](N=[N+]=[N-])[C@@H](CO)O2)c(=O)[nH]c1=O')
# ('EC50', '>', 10000, 'nM', 50587, 'COC1O[C@H]2[C@H](COC(C)(C)C)C[C@H](n3cnc4c(Cl)ncnc43)[C@H]2O1')
# ('EC50', '>', 10000, 'nM', 50587, 'O=c1ccn([C@@H]2C=C[C@H](CO)C2)c(=O)[nH]1')
# ('EC50', '>', 10000, 'nM', 50587, 'Nc1ccn([C@@H]2C=C[C@H](CO)C2)c(=O)n1')
# ('EC50', '>', 10000, 'nM', 50587, 'Cc1cn(C2CCC(CO)C2)c(=O)[nH]c1=O')
# ('EC50', '>', 10000, 'nM', 50587, 'OC[C@H]1C=C[C@@H](n2cnc3c(O)ncnc32)C1')
# ('EC50', '>', 200000, 'nM', 50587, 'Nc1nc(O)c2ncn([C@@H]3C=C[C@H](CO)C3)c2n1')
# ('EC50', '=', 900, 'nM', 50587, 'Nc1ncnc2c1ncn2[C@@H]1C=C[C@H](CO)C1')
# ('EC50', '>', 10000, 'nM', 50587, 'O=c1ccn(C2CCC(CO)C2)c(=O)[nH]1')
# ('EC50', '>', 10000, 'nM', 50587, 'Cc1cn([C@@H]2C=C[C@H](CO)C2)c(=O)[nH]c1=O')
# ('EC50', '>', 50000, 'nM', 50587, 'Nc1ncnc2c1ncn2C1CCC(CO)C1')
# ('EC50', '>', 10000, 'nM', 50587, 'OC[C@H]1C=C[C@@H](n2cnc3c(S)ncnc32)C1')
# ('EC50', '>', 10000, 'nM', 50587, 'OC[C@H]1CC[C@@H](n2cnc3c(O)ncnc32)C1')
# ('IC50', '>', 200000, 'nM', 50587, 'Nc1ncnc2c1ncn2[C@@H]1O[C@H](CO)C[C@@H]1F')
# ('IC50', '>', 200000, 'nM', 50587, 'Nc1ccn([C@@H]2O[C@H](CO)C[C@@H]2F)c(=O)n1')
# ('IC50', None, None, 'nM', 50587, 'Cc1cn([C@H]2C[C@H](N=[N+]=[N-])[C@@H](CO)O2)c(=O)[nH]c1=O')
# ('IC50', '=', 850, 'nM', 50587, 'Nc1nc(N2CCCC2)c2ncn(C3CC(O)C(CO)S3)c2n1')
# ('IC50', '=', 190, 'nM', 50587, 'CCN(C)c1nc(N)nc2c1ncn2C1CC(O)C(CO)S1')
# ('IC50', '=', 450, 'nM', 50587, 'CSc1nc(N)nc2c1ncn2C1CC(O)C(CO)S1')
# ('IC50', '=', 2.5, 'nM', 50587, 'COc1nc(N)nc2c1ncn2C1CC(O)C(CO)S1')
# ('IC50', '=', 61, 'nM', 50587, 'CCCNc1nc(N)nc2c1ncn2C1CC(O)C(CO)S1')
# ('IC50', '=', 35, 'nM', 50587, 'Nc1nc(OCC2CC2)c2ncn(C3CC(O)C(CO)S3)c2n1')
# ('IC50', '=', 1, 'nM', 50587, 'Nc1nc(Cl)c2ncn(C3CC(O)C(CO)S3)c2n1')
# ('IC50', '=', 7.2, 'nM', 50587, 'Nc1nc(NC2CC2)c2ncn(C3CC(O)C(CO)S3)c2n1')
# ('IC50', '=', 300, 'nM', 50587, 'CC(C)Nc1nc(N)nc2c1ncn2C1CC(O)C(CO)S1')
# ('IC50', '=', 4000, 'nM', 50587, 'Nc1nc(N2CCCCC2)c2ncn(C3CC(O)C(CO)S3)c2n1')
# ('IC50', '=', 58, 'nM', 50587, 'C=CCNc1nc(N)nc2c1ncn2C1CC(O)C(CO)S1')
# ('IC50', '=', 300, 'nM', 50587, 'CN(c1nc(N)nc2c1ncn2C1CC(O)C(CO)S1)C1CC1')
# ('IC50', '=', 2, 'nM', 50587, 'Nc1nc(O)c2ncn(C3CC(O)C(CO)S3)c2n1')
# ('IC50', '>', 200000, 'nM', 50587, 'O=c1[nH]c(=O)n([C@H]2O[C@@H](CO)[C@H](O)[C@H]2F)cc1F')
# ('IC50', '>', 200000, 'nM', 50587, 'Nc1ccn([C@@H]2O[C@H](CO)[C@@H](O)[C@@H]2F)c(=O)n1')
# ('IC50', '>', 200000, 'nM', 50587, 'CCc1cn([C@H]2O[C@@H](CO)[C@H](O)[C@@H]2F)c(=O)[nH]c1=O')
# ('IC50', '>', 200000, 'nM', 50587, 'O=c1[nH]c(=O)n([C@@H]2O[C@H](CO)[C@@H](O)[C@@H]2F)cc1C(F)(F)F')
# ('IC50', '>', 200000, 'nM', 50587, 'Nc1nc(=O)n([C@H]2O[C@@H](CO)[C@H](O)[C@H]2F)cc1F')
# ('IC50', '>', 200000, 'nM', 50587, 'Nc1nc(=O)n([C@@H]2O[C@H](CO)[C@@H](O)[C@@H]2F)cc1I')
# ('IC50', '>', 200000, 'nM', 50587, 'O=c1[nH]c(=O)n([C@H]2O[C@@H](CO)[C@H](O)[C@H]2F)cc1Br')
# ('IC50', '>', 200000, 'nM', 50587, 'Nc1nc(=O)n([C@H]2O[C@@H](CO)[C@H](O)[C@H]2F)cc1Cl')
# ('IC50', '>', 200000, 'nM', 50587, 'O=c1[nH]c(=O)n([C@H]2O[C@@H](CO)[C@H](O)[C@@H]2F)cc1/C=C/Br')
# ('IC50', '>', 200000, 'nM', 50587, 'Nc1nc(=O)n([C@H]2O[C@@H](CO)[C@H](O)[C@H]2F)cc1Br')
# ('IC50', '>', 200000, 'nM', 50587, 'C#Cc1cn([C@H]2O[C@@H](CO)[C@H](O)[C@H]2F)c(=O)[nH]c1=O')
# ('IC50', '>', 200000, 'nM', 50587, 'O=c1[nH]c(=O)n([C@H]2O[C@@H](CO)[C@H](O)[C@H]2F)cc1Cl')
# ('IC50', '>', 200000, 'nM', 50587, 'Cc1cn([C@@H]2O[C@H](CO)[C@@H](O)[C@@H]2F)c(=O)[nH]c1=O')
# ('IC50', '>', 200000, 'nM', 50587, 'O=c1[nH]c(=O)n([C@@H]2O[C@H](CO)[C@@H](O)[C@H]2F)cc1I')
# ('Selectivity', '>', 140, None, 50587, 'Nc1ccn([C@@H]2O[C@H](CO)[C@@H](O)[C@@H]2F)c(=O)n1')
# ('Selectivity', '>', 40, None, 50587, 'Nc1nc(=O)n([C@@H]2O[C@H](CO)[C@@H](O)[C@@H]2F)cc1I')
# ('Selectivity', '>', 2000, None, 50587, 'Cc1cn([C@@H]2O[C@H](CO)[C@@H](O)[C@@H]
)CCC(O)c2cccs2)cc(OC)c1OC')
# ('GI50', '=', 15000, 'nM', 80612, 'COc1cc(COCCC/C=C/C=C(\\C)CCC(O)c2cccs2)cc(OC)c1OC')
# ('GI50', '=', 240, 'nM', 80612, 'COc1cc(/C=N\\OC/C=C/C=C(\\C)CCC(O)c2cccs2)cc(OC)c1OC')
# ('IC50', '=', 421300, 'nM', 80612, 'O=C(O)Cc1cccc2c(=O)cc(-c3ccccc3)oc12')
# ('IC50', '=', 624600, 'nM', 80612, 'COc1ccc(-c2oc3c(CC(=O)O)cccc3c(=O)c2OC)cc1')
# ('IC50', None, None, None, 80612, 'COc1c(-c2cccc(C)c2)oc2c(CC(=O)O)cccc2c1=O')
# ('IC50', None, None, None, 80612, 'COc1c(-c2ccc(F)cc2)oc2c(CC(=O)O)cccc2c1=O')
# ('IC50', None, None, None, 80612, 'COc1c(-c2ccc(Cl)cc2)oc2c(CC(=O)O)cccc2c1=O')
# ('IC50', None, None, None, 80612, 'COc1c(-c2ccccc2Cl)oc2c(CC(=O)O)cccc2c1=O')
# ('IC50', None, None, None, 80612, 'COc1cccc(-c2oc3c(CC(=O)O)cccc3c(=O)c2OC)c1')
# ('IC50', None, None, None, 80612, 'CCOc1c(-c2ccccc2)oc2c(CC(=O)O)cccc2c1=O')
# ('IC50', None, None, None, 80612, 'COc1c(-c2cccs2)oc2c(CC(=O)O)cccc2c1=O')
# ('IC50', None, None, None, 80612, 'COc1c(-c2ccccc2)oc2c(CC(=O)O)cccc2c1=O')
# ('IC50', None, None, None, 80612, 'COc1ccccc1-c1oc2c(CC(=O)O)cccc2c(=O)c1OC')
# ('IC50', None, None, None, 80612, 'COc1c(-c2cccc(C(F)(F)F)c2)oc2c(CC(=O)O)cccc2c1=O')
# ('IC50', None, None, None, 80612, 'COc1c(-c2cccc(Cl)c2)oc2c(CC(=O)O)cccc2c1=O')
# ('IC50', None, None, None, 80612, 'COc1c(-c2ccccc2C)oc2c(CC(=O)O)cccc2c1=O')
# ('IC50', None, None, None, 80612, 'COc1c(-c2ccc(C)cc2)oc2c(CC(=O)O)cccc2c1=O')
# ('IC50', None, None, None, 80612, 'CC(C)Oc1c(-c2ccccc2)oc2c(CC(=O)O)cccc2c1=O')
# ('IC50', '=', 7, 'nM', 80613, 'CC(=O)OC1CCn2c1nc1c2C(=O)C(C)=C(N2CC2)C1=O')
# ('IC50', None, None, 'nM', 80613, 'CC1=C(N2CC2)C(=O)c2nc3n(c2C1=O)CCC3OC(N)=O')
# ('IC50', None, None, 'nM', 80613, 'CO[C@@]12[C@H](COC(N)=O)C3=C(C(=O)C(C)=C(N)C3=O)N1C[C@@H]1N[C@@H]12')
# ('IC50', '=', 7, 'nM', 80614, 'CC(=O)OC1CCn2c1nc1c2C(=O)C(C)=C(N2CC2)C1=O')
# ('IC50', None, None, 'nM', 80614, 'CC1=C(N2CC2)C(=O)c2nc3n(c2C1=O)CCC3OC(N)=O')
# ('IC50', None, None, 'nM', 80614, 'CO[C@@]12[C@H](COC(N)=O)C3=C(C(=O)C(C)=C(N)C3=O)N1C[C@@H]1N[C@@H]12')
# ('IC50', '=', 18, 'nM', 116833, 'COc1ccc(CNC(=O)[C@@H](NC(=O)[C@H](NCc2ccc(OC)c(OC)c2OC)[C@H](O)[C@H](Cc2ccccc2)NC(=O)[C@@H](NC(=O)Cc2cccc3ccccc23)C(C)(C)C)C(C)C)c(O)c1')
# ('IC50', '=', 190, 'nM', 116833, 'COc1cc(CN[C@@H](C(=O)N[C@H](C(=O)NCc2ccc(OC)cc2O)C(C)C)[C@H](O)[C@H](Cc2ccccc2)NC(=O)[C@@H](NC(=O)OCc2ccccc2)C(C)(C)C)cc(OC)c1')
# ('IC50', '=', 100, 'nM', 116833, 'COc1ccc(CN[C@@H](C(=O)N[C@H](C(=O)NCc2ccc(OC)cc2O)C(C)C)[C@H](O)[C@H](Cc2ccccc2)NC(=O)[C@@H](NC(=O)Cc2cccc3ccccc23)C(C)(C)C)cc1')
# ('IC50', '=', 1600, 'nM', 116833, 'COc1ccc(CNC(=O)[C@@H](NC(=O)[C@H](NCc2ccc(OC)cc2OC)[C@H](O)[C@H](Cc2ccccc2)NC(=O)[C@@H](NC(=O)OCc2ccccc2)C(C)(C)C)C(C)C)c(O)c1')
# ('IC50', '=', 200, 'nM', 116833, 'COc1ccc(CNC(=O)[C@@H](NC(=O)[C@H](NCc2cc(OC)c(OC)cc2OC)[C@H](O)[C@H](Cc2ccccc2)NC(=O)[C@@H](NC(=O)OCc2ccccc2)C(C)(C)C)C(C)C)c(O)c1')
# ('IC50', '>', 20000, 'nM', 116833, 'COc1ccc(CNC(=O)[C@@H](NC(=O)[C@H](NCc2ccc(-c3ccccc3)cc2)[C@H](O)[C@H](Cc2ccccc2)NC(=O)[C@@H](NC(=O)OCc2ccccc2)C(C)(C)C)C(C)C)c(O)c1')
# ('IC50', '>', 20000, 'nM', 116833, 'COc1ccc(CNC(=O)[C@@H](NC(=O)[C@H](NCc2ccc(Oc3ccccc3)cc2)[C@H](O)[C@H](Cc2ccccc2)NC(=O)[C@@H](NC(=O)OCc2ccccc2)C(C)(C)C)C(C)C)c(O)c1')
# ('IC50', '=', 50, 'nM', 116833, 'COc1ccc(CNC(=O)[C@@H](NC(=O)[C@H](NCc2cc(OC)c(OC)c(OC)c2)[C@H](O)[C@H](Cc2ccccc2)NC(=O)[C@@H](NC(=O)OCc2ccccc2)C(C)(C)C)C(C)C)c(O)c1')
# ('IC50', '=', 1600, 'nM', 116833, 'COc1ccc(CNC(=O)[C@@H](NC(=O)[C@H](NCc2ccc(C(C)C)cc2)[C@H](O)[C@H](Cc2ccccc2)NC(=O)[C@@H](NC(=O)OCc2ccccc2)C(C)(C)C)C(C)C)c(O)c1')
# ('IC50', '=', 900, 'nM', 116833, 'COc1ccc(CN[C@@H](C(=O)N[C@H](C(=O)NCc2ccc(OC)cc2O)C(C)C)[C@H](O)[C@H](Cc2ccccc2)NC(=O)[C@@H](NC(=O)OCc2ccccc2)C(C)(C)C)cc1')
# ('IC50', '>', 20000, 'nM', 116833, 'COc1ccc(CNC(=O)[C@@H](NC(=O)[C@H](NCc2ccccc2OC)[C@H](O)[C@H](Cc2ccccc2)NC(=O)[C@@H](NC(=O)OCc2ccccc2)C(C)(C)C)C(C)C)c(O)c1')
# ('IC50', '=',
 'nM', 81020, 'Nc1nc(=O)n([C@@H]2CC[C@H](CO)O2)cc1F')
# ('ED50', '=', 5200, 'nM', 81020, 'Nc1ccn([C@@H]2CC[C@H](CO)O2)c(=O)n1')
# ('ED50', '=', 2, 'nM', 81020, 'Nc1nc(=O)n([C@@H]2C=C[C@H](CO)O2)cc1F')
# ('ED50', '=', 17, 'nM', 81020, 'Nc1nc(=O)n([C@@H]2CS[C@H](CO)O2)cc1F')
# ('ED50', '=', 10, 'nM', 81020, 'Nc1ccn([C@H]2C=C[C@@H](CO)O2)c(=O)n1')
# ('ED50', '=', 36, 'nM', 81020, 'Nc1nc(=O)n([C@@H]2CC[C@H](CO)O2)cc1F')
# ('ED50', '=', 6200, 'nM', 81020, 'Nc1ccn([C@@H]2CC[C@H](CO)O2)c(=O)n1')
# ('ED50', '=', 2, 'nM', 81020, 'Nc1nc(=O)n([C@@H]2C=C[C@H](CO)O2)cc1F')
# ('ED50', '=', 30, 'nM', 81020, 'Nc1nc(=O)n([C@@H]2CS[C@H](CO)O2)cc1F')
# ('ED50', '=', 8, 'nM', 81020, 'Nc1ccn([C@H]2C=C[C@@H](CO)O2)c(=O)n1')
# ('CD50', '=', 13, 'uM', 80384, 'Cc1cn([C@H]2C[C@H](N=[N+]=[N-])[C@@H](CO)O2)c(=O)[nH]c1=O')
# ('Control', '=', 15, '%', 22226, 'CCCCCCCCCCCCCCCCOC(=O)CCC(NC(=O)c1ccc(N(C)Cc2cnc3nc(N)nc(N)c3n2)cc1)C(=O)O')
# ('Control', '=', 108, '%', 22226, 'CCCCCCCCCCCCCCCCOC(=O)CCC(NC(=O)c1ccc(N(C)Cc2cnc3nc(N)nc(N)c3n2)cc1)C(=O)O')
# ('Control', '=', 92, '%', 22226, 'CCCCCCCCCCCCCCCCOC(=O)CCC(NC(=O)c1ccc(N(C)Cc2cnc3nc(N)nc(N)c3n2)cc1)C(=O)O')
# ('Control', '=', 17, '%', 22226, 'CCCCCCCCCCCCCCCCOC(=O)CCC(NC(=O)c1ccc(N(C)Cc2cnc3nc(N)nc(N)c3n2)cc1)C(=O)O')
# ('Control', '=', 25, '%', 22226, 'CCCCCCCCCCCCCCCCOC(=O)CCC(NC(=O)c1ccc(N(C)Cc2cnc3nc(N)nc(N)c3n2)cc1)C(=O)O')
# ('Control', '=', 67, '%', 22226, 'CCCCCCCCCCCCCCCCOC(=O)CCC(NC(=O)c1ccc(N(C)Cc2cnc3nc(N)nc(N)c3n2)cc1)C(=O)O')
# ('Control', '=', 81, '%', 22226, 'CCCCCCCCCCCCCCCCOC(=O)CCC(NC(=O)c1ccc(N(C)Cc2cnc3nc(N)nc(N)c3n2)cc1)C(=O)O')
# ('Control', '=', 8, '%', 22226, 'CCCCCCCCCCCCCCCCOC(=O)CCC(NC(=O)c1ccc(N(C)Cc2cnc3nc(N)nc(N)c3n2)cc1)C(=O)O')
# ('IC50', '=', 1.55e-05, 'ppm g dm**-3', 80609, 'CC1CN1CC(O)CC1CC1')
# ('IC50', '=', 60200, 'nM', 80609, 'CC1CN1CC(O)CC1CC1')
# ('IC50', '=', 640, 'nM', 11134, 'NC(=O)N(O)CC1=Cc2cc(Oc3ccccc3)ccc2OC1')
# ('IC50', '=', 160, 'nM', 84, 'COc1cc2[nH]c(-c3csc4ccccc34)c(C=O)c2cc1-c1cnco1')
# ('IC50', '=', 600, 'nM', 68, 'COc1cc2[nH]c(Cc3ccccc3)cc2cc1-c1cnco1')
# ('IC50', '=', 8, 'nM', 68, 'COc1cc2nc(-c3ccccc3)cc(O)c2cc1-c1cnco1')
# ('IC50', '=', 500, 'nM', 68, 'COc1cc2[nH]c(-c3ccccc3)cc2cc1-c1cnco1')
# ('IC50', '=', 130, 'nM', 68, 'COc1cc2[nH]c(-c3ccccc3)c(C#N)c2cc1-c1cnco1')
# ('IC50', '=', 220, 'nM', 68, 'COc1cc2[nH]c(Cc3ccccc3)c(C#N)c2cc1-c1cnco1')
# ('IC50', '>', 1000, 'nM', 68, 'CCOC(=O)c1c(-c2ccccc2)[nH]c2cc(OC)c(-c3cnco3)cc12')
# ('IC50', '=', 360, 'nM', 68, 'COc1cc2[nH]c(Cc3ccccc3)c(C=O)c2cc1-c1cnco1')
# ('IC50', '=', 230, 'nM', 68, 'COc1cc2[nH]c(-c3ccccc3)c(C=O)c2cc1-c1cnco1')
# ('IC50', '=', 30, 'nM', 68, 'COc1cc2[nH]c(-c3csc4ccccc34)c(C=O)c2cc1-c1cnco1')
# ('IC50', '=', 64, 'nM', 68, 'COc1cc2[nH]c(-c3csc4ccccc34)c(C#N)c2cc1-c1cnco1')
# ('IC50', '=', 150, 'nM', 68, 'COc1cc2[nH]c3c(c2cc1-c1cnco1)CCCC(=O)C3')
# ('IC50', '=', 500, 'nM', 68, 'COc1cc2[nH]c(-c3csc4ccccc34)cc2cc1-c1cnco1')
# ('IC50', '=', 290, 'nM', 68, 'COc1cc2[nH]c3c(c2cc1-c1cnco1)CC(=O)CC3')
# ('Ki', '=', 0.86, 'nM', 121, 'COc1cccc2sc([C@@H]3CCN(C[C@H](O)COc4cccc5[nH]c(C)cc45)[C@@H](C)C3)cc12')
# ('Ki', '=', 7.18, 'nM', 121, 'Cc1cc2c(OC[C@@H](O)CN3CC[C@@H](c4cccc5occc45)C[C@@H]3C)cccc2[nH]1')
# ('Ki', '=', 0.53, 'nM', 121, 'Cc1cc2c(OC[C@@H](O)CN3CC[C@@H](c4cc5ccccc5s4)C[C@@H]3C)cccc2[nH]1')
# ('Ki', '=', 0.34, 'nM', 121, 'COc1cccc2ccc([C@@H]3CCN(C[C@H](O)COc4cccc5[nH]c(C)cc45)[C@@H](C)C3)cc12')
# ('Ki', '=', 4.35, 'nM', 121, 'Cc1cc2c(OC[C@H](O)CN3CC[C@@H](c4cccc5sccc45)C[C@@H]3C)cccc2[nH]1')
# ('Ki', '=', 16.75, 'nM', 121, 'O[C@@H](COc1cccc2[nH]ccc12)CN1CCC(c2cc3ccccc3s2)CC1')
# ('Ki', '=', 0.58, 'nM', 121, 'Cc1cc2c(OC[C@@H](O)CN3CC[C@@H](c4ccc5c(C)csc5c4)C[C@@H]3C)cccc2[nH]1')
# ('Ki', '=', 3.77, 'nM', 121, 'Cc1cc2c(OC[C@@H](O)CN3CC[C@@H](c4ccc5ccoc5c4)C[C@@H]3C)cccc2[nH]1')
# ('Ki', '=', 0.3, 'nM', 121, 'Cc1cc2c(OC[C@H](O)CN3CC[C@@H](c4ccc5sccc5c4)C[C@@H]3C)cccc2[nH]1')
# ('Ki', '=', 0.4, 'nM', 121, 'Cc1cc2c(OC[C@@H](O)CN3CC[C@@H](c4ccc5ccccc5c4)C[C@@H]3C)cccc2[nH]1')
# ('Ki', '=', 0.75, 'nM', 121, 'Cc1cc2c(OC[C@@H](O)CN3CC[C@@H](c4ccc5ccsc5c4)C[C@@H]3C)cccc2[nH]1')
# ('Ki', '=', 9.24, 'nM', 121, 'Cc1cc2c(OC[C@@H](O)CN3CC[C@@H](c4cccc5ccsc45)C[C@@H]3C)cccc2[nH]1')
# ('Ki', '=', 1.69, 'nM', 121, 'Cc1cc2c(OC[C@H](O)CN3CC[C@@H](c4ccc5occc5c4)C[C@@H]3C)cccc2[nH]1')
# ('Ki', '=', 0.54, 'nM', 121, 'Cc1cc2c(OC[C@@H](O)CN3CC[C@@H](c4ccc5scc(C)c5c4)C[C@@H]3C)cccc2[nH]1')
# ('Ki', None, None, 'nM', 121, 'O[C@@H](COc1cccc2[nH]ccc12)CN1CCC(c2csc3ccccc23)CC1')
# ('Activity', '=', 18.1, 'pM 10min-1', 22226, 'C=C1/C(=C\\C=C2/CCC[C@]3(C)[C@@H]([C@H](C)Cc4ccc(O)cc4)CC[C@@H]23)C[C@@H](O)C[C@@H]1O')
# ('Control', '=', 104, '%', 22226, 'C=C1/C(=C\\C=C2/CCC[C@]3(C)[C@@H]([C@H](C)Cc4ccc(O)cc4)CC[C@@H]23)C[C@@H](O)C[C@@H]1O')
# ('RCI', '=', 12, None, 80156, 'C=C1/C(=C\\C=C2/CCC[C@]3(C)[C@@H]([C@H](C)Cc4ccc(O)cc4)CC[C@@H]23)C[C@@H](O)C[C@@H]1O')
# ('Activity', '=', 16.9, 'pM 10min-1', 22226, 'C=C1/C(=C\\C=C2/CCC[C@]3(C)[C@@H]([C@H](C)Cc4cccc(O)c4)CC[C@@H]23)C[C@@H](O)C[C@@H]1O')
# ('Activity', '=', 17.2, 'pM 10min-1', 22226, 'C=C1/C(=C\\C=C2/CCC[C@]3(C)[C@@H]([C@H](C)Cc4cccc(C(C)(C)O)c4)CC[C@@H]23)C[C@@H](O)C[C@@H]1O')
# ('Activity', '=', 16.7, 'pM 10min-1', 22226, 'C=C1/C(=C\\C=C2/CCC[C@]3(C)[C@@H]([C@H](C)Cc4cccc(C)c4)CC[C@@H]23)C[C@@H](O)C[C@@H]1O')
# ('Activity', '=', 2.1, 'pM 10min-1', 22226, 'C=C1/C(=C\\C=C2/CCC[C@]3(C)[C@@H]([C@H](C)CCCC(C)(C)O)CC[C@@H]23)C[C@@H](O)C[C@@H]1O')
# ('Control', '=', 97, '%', 22226, 'C=C1/C(=C\\C=C2/CCC[C@]3(C)[C@@H]([C@H](C)Cc4cccc(O)c4)CC[C@@H]23)C[C@@H](O)C[C@@H]1O')
# ('Control', '=', 99, '%', 22226, 'C=C1/C(=C\\C=C2/CCC[C@]3(C)[C@@H]([C@H](C)Cc4cccc(C(C)(C)O)c4)CC[C@@H]23)C[C@@H](O)C[C@@H]1O')
# ('Control', '=', 96, '%', 22226, 'C=C1/C(=C\\C=C2/CCC[C@]3(C)[C@@H]([C@H](C)Cc4cccc(C)c4)CC[C@@H]23)C[C@@H](O)C[C@@H]1O')
# ('Control', '=', 12, '%', 22226, 'C=C1/C(=C\\C=C2/CCC[C@]3(C)[C@@H]([C@H](C)CCCC(C)(C)O)CC[C@@H]23)C[C@@H](O)C[C@@H]1O')
# ('Ki', '=', 280, 'nM', 104703, 'Cc1cccc(COc2nn3c(-c4cc(C)on4)nnc3c3c2C2CCC3CC2)n1')
# ('IC50', '=', 200, 'nM', 81034, 'CC1=C(N2CC2)C(=O)c2nc3n(c2C1=O)CCC3OC(N)=O')
# ('IC50', '=', 16, 'nM', 81034, 'CC(=O)OC1CCn2c1nc1c2C(=O)C(C)=C(N2CC2)C1=O')
# ('IC50', '=', 200, 'nM', 81034, 'CO[C@@]12[C@H](COC(N)=O)C3=C(C(=O)C(C)=C(N)C3=O)N1C[C@@H]1N[C@@H]12')
# ('IC50', '=', 100, 'nM', 81034, 'CC1=C(N2CC2)C(=O)c2nc3n(c2C1=O)CCC3OC(N)=O')
# ('IC50', '=', 0.6, 'nM', 81034, 'CC(=O)OC1CCn2c1nc1c2C(=O)C(C)=C(N2CC2)C1=O')
# ('IC50', '=', 100, 'nM', 81034, 'CO[C@@]12[C@H](COC(N)=O)C3=C(C(=O)C(C)=C(N)C3=O)N1C[C@@H]1N[C@@H]12')
# ('Relative activity', '=', 44, None, 22226, 'CC(=O)O[C@H]1[C@@H]2[C@H](C)[C@@H](OC(=O)/C=C/c3ccccc3)CC[C@@]2(C)[C@@H](OC(C)=O)[C@H](OC(C)=O)C2=C(C)C(=O)C[C@@H]1C2(C)C')
# ('Relative activity', '=', 77, None, 22226, 'C=C1[C@@H](OC(=O)/C=C/c2ccccc2)CC[C@@]2(C)[C@@H](OC(C)=O)[C@H](OC(C)=O)C3=C(C)C(=O)C[C@@H]([C@@H](OC(C)=O)[C@H]12)C3(C)C')
# ('Relative activity', '=', 48, None, 22226, 'CC(=O)O[C@H]1[C@@H]2[C@H](C)[C@@H](O)CC[C@@]2(C)[C@@H](OC(C)=O)[C@H](OC(C)=O)C2=C(C)C(=O)C[C@@H]1C2(C)C')
# ('Relative activity', '=', 100, None, 22226, 'COc1ccc(CCN(C)CCCC(C#N)(c2ccc(OC)c(OC)c2)C(C)C)cc1OC')
# ('Relative activity', '=', 64, None, 22226, 'C=C1[C@@H](O)CC[C@@]2(C)[C@@H](OC(C)=O)[C@H](OC(C)=O)C3=C(C)C(=O)C[C@@H]([C@@H](OC(C)=O)[C@H]12)C3(C)C')
# ('Relative activity', '=', 97, None, 22226, 'C=C1[C@@H](OC(=O)CCC2CCCCC2)CC[C@@]2(C)[C@@H](OC(C)=O)[C@H](OC(C)=O)C3=C(C)C(=O)C[C@@H]([C@@H](OC(C)=O)[C@H]12)C3(C)C')
# ('Relative activity', '=', 93, None, 22226, 'C=C1[C@@H](OC(C)=O)CC[C@@]2(C)[C@@H](OC(C)=O)[C@H](OC(C)=O)C3=C(C)C(=O)C[C@@H]([C@@H](OC(C)=O)[C@H]12)C3(C)C')
# ('Relative activity', '=', 158, None, 22226, 'C=C1[C@@H](OCOCc2ccccc2)CC[C@@]2(C)[C@@H](OC(C)=O)[C@H](OC(C)=O)C3=C(C)C(=O)C[C@@H]([C@@H](OC(C)=O)[C@H]12)C3(C)C')
# ('Relative activity', '=', 44, None, 22226, 'CC(=O)O[C@H]1[C@@H]2[C@H](C)[C@@H](OC(=O)CCc3ccccc3)CC[C@@]2(C)[C@@H](OC(C)=O)[C@H](OC(C)=O)C2=C(C)C(=O)C[C@@H]1C2(C)C')
# ('Relative activity', '=', 227, None, 22226, 'C=C1[C@@H](OC(=O)CCc2ccccc2)CC[C@@]2(C)[C@@H](OC(C)=O)[C@H](OC(C)=O)C3=C(C)C(=O)C[C@@H]([C@@H](OC(C)=O)[C@H]12)C3(C)C')
# ('Control', '=', 261, '%', 22221, 'O=C(O)C(=O)/C=C(\\O)c1ccc(Oc2ccccc2)cc1')
# ('Control', '=', 98, '%', 22221, 'O=C(O)C(=O)/C=C(\\O)c1cccc(/C(O)=C/C(=O)C(=O)O)c1')
# ('Control', '=', 65, '%', 22221, 'O=C(CC(=O)c1c[nH]c2ccc(F)cc12)c1nnn[nH]1')
# ('Control', '=', 14, '%', 22221, 'O=C(O)C(=O)/C=C(\\O)c1cccc(OCc2ccccc2)c1')
# ('Control', '=', 116, '%', 22221, 'O=C(CC(=O)c1c[nH]c2ccccc12)c1nnn[nH]1')
# ('Control', '=', 104, '%', 22221, 'CCOC(=O)C(=O)/C=C(\\O)c1c[nH]c2ccc(Cl)cc12')
# ('Control', '=', 92, '%', 22221, 'O=C(O)C(=O)/C=C(\\O)c1cccc(Br)c1')
# ('Control', '=', 1, '%', 22221, 'O=C(O)C(=O)/C=C(\\O)c1c[nH]c2ccccc12')
# ('Control', '=', 91, '%', 22221, 'O=C(O)C(=O)/C=C(\\O)c1c[nH]c2ccc(Cl)cc12')
# ('Control', '=', 133, '%', 22221, 'O=C(O)C(=O)/C=C(\\O)c1ccc(/C(O)=C/C(=O)C(=O)O)cc1')
# ('Control', '=', 61, '%', 22221, 'O=C(O)C(=O)/C=C(\\O)c1cc(/C(O)=C/C(=O)C(=O)O)c2ccccc2n1')
# ('Control', '=', 125, '%', 22221, 'O=C(/C=C(\\O)c1c[nH]c2ccc(Cl)cc12)c1nn[nH]n1')
# ('Control', '=', 7, '%', 22221, 'O=C(O)C(=O)/C=C(\\O)c1cc(OCc2ccccc2)cc(OCc2ccccc2)c1')
# ('Control', '=', 208, '%', 22221, 'O=C(O)C(=O)/C=C(\\O)c1ccc(Oc2ccccc2)cc1')
# ('Control', '=', 95, '%', 22221, 'O=C(O)C(=O)/C=C(\\O)c1cccc(/C(O)=C/C(=O)C(=O)O)c1')
# ('Control', '=', 70, '%', 22221, 'O=C(CC(=O)c1c[nH]c2ccc(F)cc12)c1nnn[nH]1')
# ('Control', '=', 25, '%', 22221, 'O=C(O)C(=O)/C=C(\\O)c1cccc(OCc2ccccc2)c1')
# ('Control', '=', 87, '%', 22221, 'O=C(CC(=O)c1c[nH]c2ccccc12)c1nnn[nH]1')
# ('Control', '=', 63, '%', 22221, 'CCOC(=O)C(=O)/C=C(\\O)c1c[nH]c2ccc(Cl)cc12')
# ('Control', '=', 103, '%', 22221, 'O=C(O)C(=O)/C=C(\\O)c1cccc(Br)c1')
# ('Control', '=', 0, '%', 22221, 'O=C(O)C(=O)/C=C(\\O)c1c[nH]c2ccccc12')
# ('Control', '=', 85, '%', 22221, 'O=C(O)C(=O)/C=C(\\O)c1c[nH]c2ccc(Cl)cc12')
# ('Control', '=', 128, '%', 22221, 'O=C(O)C(=O)/C=C(\\O)c1ccc(/C(O)=C/C(=O)C(=O)O)cc1')
# ('Control', '=', 94, '%', 22221, 'O=C(O)C(=O)/C=C(\\O)c1cc(/C(O)=C/C(=O)C(=O)O)c2ccccc2n1')
# ('Control', '=', 69, '%', 22221, 'O=C(/C=C(\\O)c1c[nH]c2ccc(Cl)cc12)c1nn[nH]n1')
# ('Control', '=', 19, '%', 22221, 'O=C(O)C(=O)/C=C(\\O)c1cc(OCc2ccccc2)cc(OCc2ccccc2)c1')
# ('IC50', '=', 600, 'nM', 22226, 'O=C(O)C(=O)/C=C(\\O)c1cccc(OCc2ccccc2)c1')
# ('IC50', '=', 2300, 'nM', 22226, 'O=C(O)C(=O)/C=C(\\O)c1cc(OCc2ccccc2)cc(OCc2ccccc2)c1')
# ('Ki', '=', 160, 'nM', 241, 'CC1=C2NCC3C(CC[C@@]4(C)C3CC[C@@H]4C(=O)N(c3ccc(Cl)cc3)C3CCCC3)[C@@]2(C)CCC1=O')
# ('Ki', '=', 1600, 'nM', 241, 'CC(C)(C)c1ccc(C(F)(F)F)cc1NC(=O)[C@H]1CCC2C3CNC4=CC(=O)CC[C@]4(C)C3CC[C@@]21C')
# ('Ki', '=', 180, 'nM', 241, 'C[C@]12CC[C@H]3[C@@H](CNC4=CC(=O)CC[C@@]43C)[C@@H]1CC[C@@H]2C(=O)OC1[C@H]2C[C@@H]3C[C@@H](C[C@H]1C3)C2')
# ('Ki', '=', 190, 'nM', 241, 'C[C@]12CCC(=O)C=C1NCC1C2CC[C@@]2(C)C1CC[C@@H]2C(=O)N1CCOCC1')
# ('Ki', '=', 19, 'nM', 241, 'CC1=C2NCC3C(CC[C@@]4(C)C3CC[C@@H]4C(=O)Nc3cc(C(F)(F)F)ccc3C(F)(F)F)[C@@]2(C)CCC1=O')
# ('Ki', '=', 11000, 'nM', 241, 'CC(C)(C)NC(=O)[C@H]1CC[C@H]2[C@@H]3CC[C@H]4NC(=O)C=C[C@]4(C)[C@H]3CC[C@]12C')
# ('Ki', '=', 510, 'nM', 241, 'C[C@]12CCC(=O)C=C1NCC1C2CC[C@@]2(C)C1CC[C@@H]2C(=O)NC(c1ccc(Cl)cc1)c1ccc(Cl)cc1')
# ('Ki', '=', 150, 'nM', 241, 'C[C@]12CCC(=O)C=C1NCC1C2CC[C@@]2(C)C1CC[C@@H]2C(=O)NC(c1ccccc1)c1ccccc1')
# ('Ki', '=', 190, 'nM', 241, 'C[C@]12CCC(=O)C(Cl)=C1NCC1C2CC[C@@]2(C)C1CC[C@@H]2C(=O)Nc1cc(C(F)(F)F)ccc1C(F)(F)F')
# ...
# ('IC50', '=', 100, 'nM', 80052, 'N#Cc1ccc2oc3cc(=O)c4ncccc4c-3nc2c1')
# ('IC50', '=', 600, 'nM', 80052, 'Cc1cccc2nc3c4cccnc4c(=O)cc-3oc12')
# ('IC50', '=', 20, 'nM', 80052, 'COc1cccc2c1C(=O)c1c(O)c3c(c(O)c1C2=O)C[C@@](O)(C(=O)CO)C[C@@H]3O[C@H]1C[C@H](N)[C@H](O)[C@H](C)O1')
# ('IC50', '=', 30, 'nM', 80052, 'O=c1cc2oc3cc([N+](=O)[O-])ccc3nc-2c2cccnc12')
# ('IC50', '=', 700, 'nM', 80052, 'Nc1ccn([C@@H]2O[C@H](CO)C[C@@H]2F)c(=O)n1')
# ('IC50', '>', 100000, 'nM', 80052, 'Nc1nc(=O)n(C2OC(CO)CC2F)cc1F')
# ('IC50', '>', 100000, 'nM', 80052, 'O=c1ccn(C2OC(CO)C=C2F)c(=O)[nH]1')
# ('IC50', '>', 100000, 'nM', 80052, 'O=c1ccn(C2OC(CO)CC2F)c(=O)[nH]1')
# ('IC50', '=', 10000, 'nM', 80052, 'Nc1ccn([C@@H]2O[C@H](CO)C=C2F)c(=O)n1')
# ('IC50', '=', 100000, 'nM', 80052, 'Cc1cn([C@@H]2O[C@H](CO)C=C2F)c(=O)[nH]c1=O')
# ('IC50', '=', 8.5, 'nM', 80052, 'Cc1cn([C@H]2C[C@H](N=[N+]=[N-])[C@@H](CO)O2)c(=O)[nH]c1=O')
# ('IC50', '>', 100000, 'nM', 80052, 'Cl.Nc1ccn(C2OC(CO)CC2F)c(=O)n1')
# ('IC50', '>', 100000, 'nM', 80052, 'O=c1ccn(C2OC(CO)C(F)C2F)c(=O)[nH]1')
# ('IC50', '=', 125, 'nM', 80052, 'Nc1ccn([C@H]2CC[C@@H](CO)O2)c(=O)n1')
# ('IC50', '=', 10000, 'nM', 80052, 'Nc1ccn(C2OC(CO)C(F)C2F)c(=O)n1')
# ('IC50', '=', 2, 'nM', 80052, 'CC(C)(C)NC(=O)[C@H]1C[C@@H]2CCCC[C@@H]2CN1C[C@@H](O)[C@H](Cc1ccccc1)NC(=O)[C@H](CC(N)=O)NC(=O)c1ccc2ccccc2n1')
# ('IC50', '=', 200000, 'nM', 80052, 'O=c1c2cccn2c2cccc(F)c2n1CC/N=C(\\S)Nc1ccc(Br)cn1')
# ('IC50', '=', 18000, 'nM', 80052, 'O=C(NNc1nc2ccccc2n2cccc12)c1cnccn1')
# ('IC50', '=', 11000, 'nM', 80052, 'O=c1c2cccn2c2ncccc2n1CCNC(=S)Nc1ccc(Br)cn1')
# ('IC50', '=', 15000, 'nM', 80052, 'O=c1c2cccn2c2ccc(F)cc2n1CC/N=C(\\S)Nc1ccc(Br)cn1')
# ('IC50', '=', 7000, 'nM', 80052, 'O=c1c2cccn2c2ccc(Cl)cc2n1CCNC(=S)Nc1ccc(Br)cn1')
# ('IC50', '=', 93000, 'nM', 80052, 'S=C(NCCOc1nc2cc(Cl)ccc2n2cccc12)Nc1ccc(Br)cn1')
# ('IC50', '=', 125000, 'nM', 80052, 'Fc1cccc2c1nc(OCC/N=C(\\S)Nc1ccc(Br)cn1)c1cccn12')
# ('IC50', '=', 88000, 'nM', 80052, 'O=c1c2nccn2c2ccccc2n1CCNC(=S)Nc1ccc(Br)cn1')
# ('IC50', '=', 21000, 'nM', 80052, 'O=c1c2cccn2c2c(F)cccc2n1CC/N=C(\\S)Nc1ccc(Br)cn1')
# ('IC50', '=', 50000, 'nM', 80052, 'CC(C)=CCN1Cc2c(Cl)ccc3[nH]c(=S)n(c23)C[C@@H]1C')
# ('IC50', '=', 17000, 'nM', 80052, 'O=c1c2cccn2c2ccccc2n1CCNC(=S)Nc1ccc(Br)cn1')
# ('IC50', '>', 100000, 'nM', 80052, 'Cc1cn([C@H]2C[C@H](N=[N+]=[N-])[C@@H](CO)O2)c(=O)[nH]c1=O')
# ('IC50', '=', 9000, 'nM', 80052, 'CCN1c2ncc(CCc3ccncc3)cc2C(=O)N(C)c2ccc(Cl)nc21')
# ('IC50', '=', 39, 'nM', 80052, 'CCN1c2ncc(CCc3cccc(NC(N)=O)c3)cc2C(=O)N(C)c2ccc(Cl)nc21')
# ('IC50', '=', 25, 'nM', 80052, 'CCN1c2ncc(CCc3ccncc3)cc2C(=O)N(C)c2cccnc21')
# ('IC50', '=', 12, 'nM', 80052, 'CCN1c2ncc(CCc3ccccc3)cc2C(=O)N(C)c2ccc(Cl)nc21')
# ('IC50', '=', 50, 'nM', 80052, 'CCN1c2ncc(COc3ccccc3)cc2C(=O)N(C)c2ccc(Cl)nc21')
# ('IC50', '=', 19, 'nM', 80052, 'CCN1c2ncc(COc3cccc(N)c3)cc2C(=O)N(C)c2ccc(Cl)nc21')
# ('IC50', '=', 6, 'nM', 80052, 'CCN1c2ncc(COc3ccncc3)cc2C(=O)N(C)c2ccc(Cl)nc21')
# ('IC50', '=', 5, 'nM', 80052, 'CCN1c2ncc(CSc3ccccc3)cc2C(=O)N(C)c2ccc(Cl)nc21')
# ('IC90', '=', 113, 'nM', 80052, 'CCN1c2ncc(COc3ccccc3)cc2C(=O)N(C)c2ccc(Cl)nc21')
# ('IC90', '=', 36, 'nM', 80052, 'CCN1c2ncc(COc3cccc(N)c3)cc2C(=O)N(C)c2ccc(Cl)nc21')
# ('IC90', '=', 24, 'nM', 80052, 'CCN1c2ncc(COc3ccncc3)cc2C(=O)N(C)c2ccc(Cl)nc21')
# ('IC90', '=', 13, 'nM', 80052, 'CCN1c2ncc(CSc3ccccc3)cc2C(=O)N(C)c2ccc(Cl)nc21')
# ('SI', '=', 3720, None, 80052, 'S=C(NCCOc1nc2cc(Cl)ccc2n2cccc12)Nc1ccc(Br)cn1')
# ('IC100', '=', 0.1, 'uM', 80052, 'CCN1c2ncccc2-c2nccn2-c2ccc(OC)nc21')
# ('IC100', '=', 0.1, 'uM', 80052, 'CCN1c2ncccc2-c2nccn2-c2ccc(N(C)C)nc21')
# ('IC100', '=', 0.01, 'uM', 80052, 'CCN1c2ncccc2-c2ncc(C)n2-c2ccc(OC)nc21')
# ('IC100', '=', 0.01, 'uM', 80052, 'CCN1c2ncccc2-c2ncc(C)n2-c2cccnc21')
# ('IC100', '=', 0.1, 'uM', 80052, 'Cc1ccnc2c1NC(=O)c1cccnc1N2C1CC1')
# ('IC100', '=', 0.1, 'uM', 80052, 'CCN1c2ncccc2-c2ncc(C)n2-c2ccc(N(C)C)nc21')
# ('IC100', '=', 0.1, 'uM', 80052, 'CCN1c2ncccc2-c2ncc(C)n2-c2ccc(O)nc21')
# ('IC100', '=', 0.1, 'uM', 80052, 'CCN1c2ncccc2-c2nccn2-c2ccc(N3CCCC3)nc21')
# ('IC100', '=', 0.1, 'uM', 80052, 'CCN1c2ncccc2-c2nccn2-c2cccnc21')
# ('IC100', '=', 0.1, 'uM', 80052, 'CCN1c2ncccc2-c2nccn2-c2c(C)ccnc21')
# ('CD50', '=', 25, 'uM', 80052, 'CC(C)[C@H](COCc1ccccc1)NC(=O)C(F)(F)C(=O)C(Cc1ccc(OCc2ccccc2)cc1)NC(=O)[C@@H](NC(=O)OCc1ccccc1)C(C)C')
# ('ED50', '=', 0.009, 'uM', 80052, 'CC(C)[C@H](COCc1ccccc1)NC(=O)C(F)(F)C(=O)C(Cc1ccc(OCc2ccccc2)cc1)NC(=O)[C@@H](NC(=O)OCc1ccccc1)C(C)C')
# ('Inhibition', '=', 57, '%', 22226, 'O=C(O)CCCOc1cccc(-n2cnc(-c3ccccc3)c2-c2ccccc2)c1')
# ('Inhibition', '=', 23, '%', 22226, 'O=C(O)CCCCOc1cccc(-n2cnc(-c3ccccc3)c2-c2ccccc2)c1')
# ('Inhibition', '=', 1, '%', 22226, 'O=C(O)COc1cccc(CCc2nc(-c3ccc(C(F)(F)F)cc3)c(-c3ccc(C(F)(F)F)cc3)o2)c1')
# ('Inhibition', '=', 32, '%', 22226, 'CSc1ccc(-c2nc(CCc3cccc(OCC(=O)O)c3)oc2-c2ccc(SC)cc2)cc1')
# ('Inhibition', '=', 0, '%', 22226, 'O=C(O)COc1cccc(CCc2nc(-c3cccc(Cl)c3)c(-c3cccc(Cl)c3)o2)c1')
# ('Inhibition', '=', 30, '%', 22226, 'Cc1cccc(-c2nc(CCc3cccc(OCC(=O)O)c3)oc2-c2cccc(C)c2)c1')
# ('Inhibition', '=', 32, '%', 22226, 'O=C(O)CCCCOc1ccc(-n2cnc(-c3ccccc3)c2-c2ccccc2)cc1')
# ('Inhibition', '=', 25, '%', 22226, 'O=C(O)COc1cccc(CCc2nc(C3CCCCC3)c(C3CCCCC3)o2)c1')
# ('Inhibition', '=', 18, '%', 22226, 'O=C(O)COc1cccc(-n2cnc(-c3ccccc3)c2-c2ccccc2)c1')
# ('Inhibition', '=', 23, '%', 22226, 'O=C(O)COc1ccc(-n2cnc(-c3ccccc3)c2-c2ccccc2)cc1')
# ('Inhibition', '=', 3.6, '%', 10679, 'CC(C)C[C@H](NC(=O)[C@H](Cc1c[nH]cn1)NC(=O)CNC(=O)[C@@H](NC(=O)[C@H](C)NC(=O)[C@H](Cc1c[nH]c2ccccc12)NC(=O)[C@@H](N)CCC(N)=O)C(C)C)C(N)=O')
# ('IC50', '=', 7.9, 'nM', 10580, 'Cc1nc(-c2ccncc2)nc(C)c1C(=O)N1CCC(C)(N2CCC(N(c3ccccc3)c3ccccc3)CC2)CC1')
# ('IC50', '=', 200, 'nM', 22221, 'COc1ccc(-c2oc3cc(O)c(OC)c(O)c3c(=O)c2OC)cc1O')
# ('IC50', '>', 1000, 'nM', 80053, 'COc1ccc2c(C(O)c3ccc(OC)c(O)c3)c(-c3cc(OC)c(OC)c(OC)c3)sc2c1')
# ('IC50', '=', 18000, 'nM', 80053, 'COc1cc2c(c(OC)c1OC)-c1ccc(SC)c(=O)cc1C(=O)CC2')
# ('IC50', '=', 3400, 'nM', 80053, 'COc1cc2c(c(OC)c1OC)-c1ccc(SC)c(=O)cc1[C@@H](OC(C)=O)CC2')
# ('IC50', '=', 4500, 'nM', 80053, 'COc1cc2c(c(OC)c1OC)-c1ccc(SC)c(=O)cc1[C@@H](NC(C)=O)CC2')
# ('IC50', '=', 15000, 'nM', 80053, 'COc1cc2c(c(OC)c1OC)-c1ccc(OC)c(=O)cc1[C@@H](NC(C)=O)CC2')
# ('IC50', '=', 29000, 'nM', 80053, 'CCCC(=O)O[C@H]1CCc2cc(OC)c(OC)c(OC)c2-c2ccc(SC)c(=O)cc21')
# ('IC50', '=', 27000, 'nM', 80053, 'COc1cc2c(c(OC)c1OC)-c1ccc(SC)c(=O)cc1[C@@H](OC(=O)c1cccnc1)CC2')
# ('IC50', '=', 38000, 'nM', 80053, 'COc1cc2c(c(OC)c1OC)-c1ccc(SC)c(=O)cc1[C@@H](N)CC2')
# ('IC50', '=', 40000, 'nM', 80053, 'COc1cc2c(c(OC)c1OC)-c1ccc(SC)c(=O)cc1[C@H](OC(C)=O)CC2')
# ('IC50', '=', 120000, 'nM', 80053, 'COc1cc2c(c(OC)c1OC)-c1ccc(SC)c(=O)cc1[C@H](O)CC2')
# ('IC50', '=', 2800, 'nM', 80053, 'COc1cc2c(c(OC)c1OC)-c1ccc(SC)c(=O)cc1[C@@H](O)CC2')
# ('IC50', '=', 2800, 'nM', 80053, 'COc1cc2c(c(OC)c1OC)-c1ccc(SC)c(=O)cc1[C@@H](OC(=O)c1ccncc1)CC2')
# ('IC50', '=', 1610, 'nM', 80054, 'CCc1cnc(CSc2cnc(NC(C)=O)s2)o1')
# ('IC50', '=', 86, 'nM', 80054, 'CN1CC[C@H](c2c(O)cc(O)c3c(=O)cc(-c4ccccc4Cl)oc23)[C@H](O)C1')
# ('GI50', '=', 1490, 'nM', 80055, 'COc1cccc2cc3cccc(C(=O)NCCCN(C)CCCNC(=O)c4cccc5cc6cccc(OC)c6nc45)c3nc12')
# ('GI50', '=', 247, 'nM', 80055, 'Cc1cc(C(=O)NCCCN(C)CCCNC(=O)c2cc(C)cc3cc4ccccc4nc23)c2nc3ccccc3cc2c1')
# ('GI50', '=', 669, 'nM', 80055, 'Cc1ccc2cc3cccc(C(=O)NCCCN(C)CCCNC(=O)c4cccc5cc6ccc(C)cc6nc45)c3nc2c1')
# ('GI50', '<', 10, 'nM', 80055, 'Cc1cccc2cc3cccc(C(=O)NCCCN(C)CCCNC(=O)c4cccc5cc
H](O)CC3=C[C@H](C)OC3=O)O2)O1')
# ('ED50', '>', 20, 'ug ml-1', 80055, 'CCCCCCCC(O)C(O)CCCC[C@@H](O)[C@H]1CC[C@H](CCCCCCCCCCCCC2=C[C@H](C)OC2=O)O1')
# ('ED50', '=', 9.8, 'ug ml-1', 80055, 'CCCCCCCCCCCC[C@@H](O)[C@H]1CC[C@H]([C@H](O)CCCC[C@H](O)CCCCC[C@@H](O)CC2=CC(C)OC2=O)O1')
# ('ED50', '>', 20, 'ug ml-1', 80055, 'CCCCCC(O)C(O)CCCCCC[C@@H](O)[C@H]1CC[C@H](CCCCCCCCCC[C@@H](O)CC2=C[C@H](C)OC2=O)O1')
# ('ED50', '>', 20, 'ug ml-1', 80055, 'CCCCC(O)C(O)C/C=C\\CC[C@H](O)[C@@H]1CC[C@@H](CCCCCCCCCCCC[C@H](O)CC2=C[C@H](C)OC2=O)O1')
# ('ED50', '>', 20, 'ug ml-1', 80055, 'CCCCCCCCCCCCC(O)C(O)CCC(O)[C@H]1CC[C@H](CCCCCCC[C@@H](O)CC2=C[C@H](C)OC2=O)O1')
# ('ED50', '=', 13.5, 'ug ml-1', 80055, 'CCCCCC[C@H](O)CCC[C@H](O)[C@H]1CC[C@H]([C@H]2CC[C@H]([C@H](O)CCCCCCCCCCCCC3=C[C@H](C)OC3=O)O2)O1')
# ('ED50', '>', 20, 'ug ml-1', 80055, 'CCCCCCCCCCCC[C@@H](O)[C@H]1CC[C@H]([C@H](O)CCCCC(=O)CCCCC[C@@H](O)CC2=C[C@H](C)OC2=O)O1')
# ('ED50', '>', 20, 'ug ml-1', 80055, 'CCCCCCCCCCCC[C@@H](O)[C@H]1CC[C@@H]([C@@H](O)CCCCC(=O)CCCCCCCC2=C[C@H](C)OC2=O)O1')
# ('ED50', '=', 16, 'ug ml-1', 80055, 'CCCCCCCCCCCCCC[C@@H](O)[C@H]1CC[C@H]([C@H](O)CCCCC(O)CCCCCC(O)CC2=C[C@H](C)OC2=O)O1')
# ('ED50', '=', 17.8, 'ug ml-1', 80055, 'CCCCCCCCC[C@H](O)[C@@H]1CC[C@@H]([C@@H]2CC[C@@H](CCCCCCCCCC[C@H](O)CC3=C[C@H](C)OC3=O)O2)O1')
# ('ED50', '=', 16.8, 'ug ml-1', 80055, 'CCCCCCCCCC[C@@H](O)[C@@H]1CC[C@@H]([C@@H]2CC[C@@H]([C@H](O)CCCCCCCCCC(O)CC3=CC(C)OC3=O)O2)O1')
# ('ED50', '>', 20, 'ug ml-1', 80055, 'CCCCCC[C@@H](O)CCC[C@H](O)[C@@H]1CC[C@@H]([C@H](O)CC[C@@H](O)[C@@H]2CC[C@@H](CCCCCCCCCC3=C[C@@H](C)OC3=O)O2)O1')
# ('ED50', '=', 16.3, 'ug ml-1', 80055, 'CCCCCCCCCCCC[C@@H](O)[C@H]1CC[C@H]([C@H](O)CCCCCC(O)CCCC[C@@H](O)CC2=C[C@H](C)OC2=O)O1')
# ('ED50', '=', 19, 'ug ml-1', 80055, 'CCCCCCCC/C=C\\CC[C@H](O)[C@@H]1CC[C@@H]([C@H](O)CCCCC(O)CCCCCC(O)CC2=C[C@H](C)OC2=O)O1')
# ('ED50', '>', 20, 'ug ml-1', 80055, 'CCCCCCCCCCCC[C@@H](O)[C@H]1CC[C@H]([C@H](O)CCCCCCCCCC[C@@H](O)CC2=C[C@H](C)OC2=O)O1')
# ('ED50', '=', 13.9, 'ug ml-1', 80055, 'CCCCCCCCCCCC[C@@H](O)[C@H]1CC[C@H]([C@H](O)CCCCC(O)CCCCCCCC2=C[C@H](C)OC2=O)O1')
# ('ED50', '=', 17.3, 'ug ml-1', 80055, 'CCCCCCCCCCCC[C@@H](O)[C@H]1CC[C@@H]([C@@H](O)CCCCCCC(O)CCCCC[C@@H](O)CC2=C[C@H](C)OC2=O)O1')
# ('ED50', '>', 20, 'ug ml-1', 80055, 'CCCCCCCCCCCCCC[C@@H](O)[C@H]1CC[C@H]([C@H](O)CCC(O)CCCCCCCC2=C[C@H](C)OC2=O)O1')
# ('ED50', '>', 20, 'ug ml-1', 80055, 'CCCCCCCC(O)C(O)CC[C@H](O)[C@@H]1CC[C@@H](CCCCCCCCCC[C@H](O)CC2=C[C@H](C)OC2=O)O1')
# ('ED50', '=', 15.3, 'ug ml-1', 80055, 'CCCCCCCCCCCC[C@H](O)[C@@H]1CC[C@@H]([C@@H](O)CCCCCCC(O)CCCCC[C@@H](O)CC2=C[C@H](C)OC2=O)O1')
# ('NA', None, None, None, 80055, 'CCCCCC(O)C(O)CCCCCC[C@H](O)[C@@H]1CC[C@H](CCCCCCCCCC[C@H](O)CC2=C[C@H](C)OC2=O)O1')
# ('NA', None, None, None, 80055, 'CCCCCCCCCCCC[C@H](O)[C@@H]1CC[C@@H]([C@@H](O)CCCCC(=O)CCCCCC2CC(CC(C)=O)C(=O)O2)O1')
# ('NA', None, None, None, 80055, 'CCCCCCCCCCCC[C@@H](O)[C@H]1CC[C@H]([C@H](O)CCCCCCCCCCCCC2=C[C@H](C)OC2=O)O1')
# ('NA', None, None, None, 80055, 'CCCCCCCCC[C@H](O)[C@@H]1CC[C@H]([C@H]2CC[C@@H](CCCCCCCCCC[C@H](O)CC3=C[C@H](C)OC3=O)O2)O1')
# ('NA', None, None, None, 80055, 'CCCCC/C=C\\CCC(O)C(O)CCCC[C@@H](O)[C@@H]1CC[C@@H](CCCCCCCCCCCCC2=C[C@H](C)OC2=O)O1')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[55], line 25
#      22 cursor.execute(query)
#      24 # Fetch and print the results
# ---> 25 rows = cursor.fetchall()
#      26 for row in rows:
#      27     print(row)
#
# KeyboardInterrupt:

# %%
import sqlite3
def filter_tid(tid):
    if id_mapping_tools.tid_to_af_uniprot(tid):
        return True
    return False

# Path to the original database
original_db_path = 'data/chembl/chembl_33.db'

# Path to the new database
new_db_path = 'data/chembl/smiles_alphafold_v4_human_uniprot_chembl_bioactivities.db'

# Connect to the original database
conn_original = sqlite3.connect(original_db_path)
cursor_original = conn_original.cursor()

# Connect to the new database (this will create the file if it doesn't exist)
conn_new = sqlite3.connect(new_db_path)
cursor_new = conn_new.cursor()

# Create a new table in the new database
cursor_new.execute("""
CREATE TABLE IF NOT EXISTS bioactivites (
    canonical_smiles VARCHAR(4000),
    af_4_human_uniprot VARCHAR(10),
    activity_type VARCHAR(250),
    activity_relation VARCHAR(50),
    activity_value NUMERIC,
    activity_unit VARCHAR(100),
    molregno BIGINT,
    mw_freebase NUMERIC(9, 2),
    alogp NUMERIC(9, 2),
    hba INTEGER,
    hbd INTEGER,
    psa NUMERIC(9, 2),
    rtb INTEGER,
    ro3_pass VARCHAR(3),
    num_ro5_violations SMALLINT,
    cx_most_apka NUMERIC(9, 2),
    cx_most_bpka NUMERIC(9, 2),
    cx_logp NUMERIC(9, 2),
    cx_logd NUMERIC(9, 2),
    molecular_species VARCHAR(50),
    full_mwt NUMERIC(9, 2),
    aromatic_rings INTEGER,
    heavy_atoms INTEGER,
    qed_weighted NUMERIC(3, 2),
    mw_monoisotopic NUMERIC(11, 4),
    full_molformula VARCHAR(100),
    hba_lipinski INTEGER,
    hbd_lipinski INTEGER,
    num_lipinski_ro5_violations SMALLINT,
    np_likeness_score NUMERIC(3, 2)
);
""")

total_rows = 6749321  # Adjust based on the total number of rows

for x in tqdm(range(0, total_rows, 2000000), desc="loading"):
    query = f"""
    SELECT compound_structures.canonical_smiles, assays.tid, activities.standard_type, activities.standard_relation, activities.standard_value, activities.standard_units, compound_properties.*
    FROM activities 
    JOIN assays ON activities.assay_id = assays.assay_id
    JOIN compound_structures ON activities.molregno = compound_structures.molregno
    JOIN compound_properties ON activities.molregno = compound_properties.molregno
    WHERE assays.assay_organism = 'Homo sapiens'
    LIMIT 2000000 OFFSET {x};
    """
    cursor_original.execute(query)
    rows = cursor_original.fetchall()
    
    for row in rows:
        if filter_tid(row[1]):  # Replace tid_column_index with the index of tid in the row
            new_row = list(row)
            new_row[1] = id_mapping_tools.tid_to_af_uniprot(new_row[1])

            cursor_new.execute("INSERT INTO bioactivites VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)", tuple(new_row))  # Adjust the placeholders based on the number of columns

# Commit changes to the new database and close both connections
conn_new.commit()
conn_original.close()
conn_new.close()
# Out:
# loading:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
# Replace 'your_chembl_database_file.db' with the path to your ChEMBL SQLite file
database_path = 'data/chembl/smiles_alphafold_v4_human_uniprot_chembl_bioactivities.db'

# Connect to the SQLite database
conn = sqlite3.connect(database_path)

# Create a cursor object
cursor = conn.cursor()

# Execute a query (example: selecting 10 rows from a table)
query = "SELECT COUNT(*) FROM bioactivites LIMIT 30;"  # Replace 'your_table_name' with the actual table name
cursor.execute(query)

# Fetch and print the results
rows = cursor.fetchall()
for row in rows:
    print(row)

# Close the connection
conn.close()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[79], line 12
#      10 # Execute a query (example: selecting 10 rows from a table)
#      11 query = "SELECT COUNT(*) FROM bioactivites LIMIT 30;"  # Replace 'your_table_name' with the actual table name
# ---> 12 cursor.execute(query)
#      14 # Fetch and print the results
#      15 rows = cursor.fetchall()
#
# OperationalError: no such table: bioactivites

# %%
3582142
